# %% [markdown]
# # Construção de variávies sócio econômicas para a análise exploratória de preços de imóveis na cidade do Rio de Janeiro.

# %% [markdown]
# ## Variável 'Média de Anos de Estudo por Bairro'

# %%
import zap_util as z
from xlrd import open_workbook

# %%
b = z.get('select gid,nome_s as nome from bairro', id_=None)
wb = open_workbook('./../armazen_dados_rj/488.xls', encoding_override=True)
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
anos = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_anos_estudo'] = anos

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 158 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Freguesia _Ilha_',
#  'Freguesia _Jacarepagua_',
#  'Gericino',
#  'Lapa',
#  'Osvaldo Cruz',
#  'Vasco da Gama'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Freguesia (Ilha)', 'Freguesia (Jacarepagua)', 'Oswaldo Cruz'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Freguesia (Ilha)', 'nome'] = 'Freguesia _Ilha_'
df.loc[df.nome == 'Freguesia (Jacarepagua)','nome'] = 'Freguesia _Jacarepagua_'
df.loc[df.nome == 'Oswaldo Cruz','nome'] = 'Osvaldo Cruz'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Gericino', 'Lapa', 'Vasco da Gama'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
# Tratamento dos valores ausentes.

def media(coluna, bairros):
    soma = 0
    for v in bairros:
        soma += b[b.nome==v][coluna].values[0]
    return soma/len(bairros)


# Gericino
b.ix[b.nome=='Gericino','viz_anos_estudo'] = media('viz_anos_estudo',['Bangu','Padre Miguel', 'Realengo'])

# Lapa
b.ix[b.nome=='Lapa','viz_anos_estudo'] = media('viz_anos_estudo',['Centro', 'Santa Teresa', 'Gloria'])

# Vasco da Gama
b.ix[b.nome=='Vasco da Gama', 'viz_anos_estudo'] = media('viz_anos_estudo', ['Sao Cristovao','Caju','Benfica'])

# %% [markdown]
# # Variável 'Percentual Alfabetização'

# %%
wb = open_workbook('./../armazen_dados_rj/3132.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
perc_alf = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_perc_alf'] = perc_alf

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 160 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa', 'Vila Kosmos'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Vila Cosmos'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Vila Cosmos', 'nome'] = 'Vila Kosmos'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
# Tratamento dos valores ausentes.

# Lapa
b.ix[b.nome=='Lapa','viz_perc_alf'] = media('viz_perc_alf',['Centro', 'Santa Teresa', 'Gloria'])

# %% [markdown]
# # Variável 'Rendimento Nominal Médio'

# %%
wb = open_workbook('./../armazen_dados_rj/3151.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
rend = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_renda'] = rend

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 160 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa', 'Sao Cristovao'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Imperial de Sao Cristovao'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Imperial de Sao Cristovao', 'nome'] = 'Sao Cristovao'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
# Tratamento dos valores ausentes.

# Lapa
b.ix[b.nome=='Lapa','viz_renda'] = media('viz_renda',['Centro', 'Santa Teresa', 'Gloria'])

# %% [markdown]
# # Variável 'Saneamento'.

# %%
wb = open_workbook('./../armazen_dados_rj/3169.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
sanea = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_sanea'] = sanea


print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 161 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# set()

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
# Arquivo não tem dados válidos para Lapa.
df.loc[df.nome == 'Lapa','viz_sanea'] = None
df['viz_sanea'] = df['viz_sanea'].astype(float)

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
# Tratamento dos valores ausentes.

# Lapa
b.ix[b.nome=='Lapa','viz_sanea'] = media('viz_sanea',['Centro', 'Santa Teresa', 'Gloria'])

# %% [markdown]
# # Variável IDH

# %%
wb = open_workbook('./../armazen_dados_rj/1172.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
idh = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_idh'] = idh


print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 159 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Gericino', 'Lapa'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
# Tratamento de valores ausentes.

# Gericino
b.ix[b.nome=='Gericino','viz_idh'] = media('viz_idh',['Bangu','Padre Miguel', 'Realengo'])

# Lapa
b.ix[b.nome=='Lapa','viz_idh'] = media('viz_idh',['Centro', 'Santa Teresa', 'Gloria'])

# %%
# Verificar se restou algum valor nulo.
b.isnull().sum()
# Out:
# gid                0
# nome               0
# viz_anos_estudo    0
# viz_perc_alf       0
# viz_renda          0
# viz_sanea          0
# viz_idh            0
# dtype: int64

# %% [markdown]
# # Índices de Criminalidade
#
# Os índices de criminalidade foram obtidos do Institudo de Segurança Pública do RJ pelo notebook [Capturar Info Bairros](Capturar Info Bairros.ipynb).

# %%
# AISPs da cidade do Rio de Janeiro.
aisp_idx = [2,3,4,5,6,9,14,16,17,18,19,22,23,27,31,40,41]

from xlrd import open_workbook, cellname

# Repositório dos arquivos baixados.
DIR = './../instituto_seguranca_publica/xls/'

# Construir nomes dos arquivos.
arqs = ['2013{:0>2}'.format(i) for i in range(10,13)]+['2014{:0>2}'.format(i) for i in range(1,11)]

# Helper para indexar coluna no Excel por sua letra.
def colindex(colname):
    cols_ = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    return cols_.index(colname)


# Índices de criminalidade por AISP.
indices = {}

# Carregar os índices a partir dos arquivos.
for arq in arqs[:]:
    
    wb = open_workbook(DIR+arq+'.xls')
    
    for i in aisp_idx[:]:
        crimes = indices.setdefault(i, {})
        try:
            ws = wb.sheet_by_name(u'Aisp {}'.format(i))
        except:
            ws = wb.sheet_by_name(u'Aisp{}'.format(i))
        col = colindex('S')
        crimes['viz_crm_violento'] = crimes.setdefault('viz_crm_violento',0) + \
            sum(ws.col_values(col,6, 11))
        crimes['viz_crm_roubo'] = crimes.setdefault('viz_crm_roubo',0) + \
            sum(ws.col_values(col, 22, 33))
    
        del ws
    del wb
    
df_aisp = z.pd.DataFrame(indices).T    
df_aisp['aisp'] = df_aisp.index

# %%
# De <-> para entre AISP e Bairro.
aisp_bairro = z.pd.DataFrame.from_csv('./../instituto_seguranca_publica/aisp_bairro.csv', index_col=None)

# Remover acentos.
aisp_bairro['nome'] =  aisp_bairro.nome.apply(z.remove_acento)

# %%
# Listar bairros no banco de dados mas não de<->para.
# As correções necessárias foram feitas.
set(b.nome.tolist()) - set(aisp_bairro.nome.tolist())
# Out:
# set()

# %%
# Listar bairros no banco de dados mas não de<->para.
# As correções necessárias foram feitas.
set(aisp_bairro.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
# Bairros em um único AISP.
g = aisp_bairro.groupby('nome')
s = g.size()
df_bairro = b[['gid','nome']]
nomes_unico_aisp = s[s == 1].index.tolist()
b1 = z.pd.merge(df_bairro[df_bairro.nome.isin(nomes_unico_aisp)], aisp_bairro, on=['nome'], how='left')
b1_aisp = z.pd.merge(b1, df_aisp, on=['aisp'], how='left')
del b1_aisp['aisp'],b1

# %%
# Calcular média dos indicadores para bairros em mais de um AISP.

data = []
for i in s[s>1].index.tolist():
    aispids = g.get_group(i).aisp.unique().tolist()
    data.append({'nome':i,
            'gid':b[(b.nome==i)].index.tolist()[0],
            'viz_crm_roubo':df_aisp.loc[aispids].mean().viz_crm_roubo,
            'viz_crm_violento':df_aisp.loc[aispids].mean().viz_crm_roubo
            })
    
b2_aisp = z.pd.DataFrame(data)

# %%
# Juntar tudo para salvar no banco.
df = z.pd.concat([b1_aisp, b2_aisp])
df.index = df.gid
del df['gid']
df
# Out:
#                      nome  viz_crm_roubo  viz_crm_violento
# gid
# 1                 Paqueta    4871.753940       1730.203982
# 4                  Galeao     506.370607        528.446144
# 8            Campo Grande     548.152777        750.171811
# 15       Jardim Guanabara     506.370607        528.446144
# 25           Pitangueiras     506.370607        528.446144
# 20                  Bangu    1422.348026        630.102144
# 33        Parque Anchieta    2138.462156        538.945453
# 28                  Penha    1247.621093        539.180020
# 30                Ribeira     506.370607        528.446144
# 41                   Mare    1005.882404        548.783181
# 42           Vila Militar    1422.348026        630.102144
# 46               Realengo    1422.348026        630.102144
# 43   Cidade Universitaria     506.370607        528.446144
# 50              Paciencia     374.149360        724.667841
# 53               Vaz Lobo    2121.794262        724.358959
# 63             Santa Cruz     374.149360        724.667841
# 67      Campo dos Afonsos    1422.348026        630.102144
# 70        Engenheiro Leal    2121.794262        724.358959
# 79               Campinho    2121.794262        724.358959
# 90               Inhoaiba     548.152777        750.171811
# 106               Taquara     646.448508        764.408423
# 116          Santa Teresa    4871.753940       1730.203982
# 124              Flamengo    1180.675882        423.449787
# 127         Vargem Grande    1167.358492        644.473336
# 128     Alto da Boa Vista    1124.097257        588.673608
# 126             Guaratiba     374.149360        724.667841
# 134              Sepetiba     374.149360        724.667841
# 140       Jardim Botanico     777.602554        567.540861
# 132                  Urca    1180.675882        423.449787
# 136           Jacarepagua     646.448508        764.408423
# ..                    ...            ...               ...
# 114                Gloria    1180.675882        423.449787
# 115          Rio Comprido    1740.699949        715.936741
# 117               Estacio    1740.699949        715.936741
# 119               Catumbi    1740.699949        715.936741
# 120                Grajau    1124.097257        588.673608
# 121             Pechincha     646.448508        764.408423
# 122               Andarai    1124.097257        588.673608
# 123                Catete    1180.675882        423.449787
# 125           Laranjeiras    1180.675882        423.449787
# 129           Cosme Velho    1180.675882        423.449787
# 133        Cidade de Deus     646.448508        764.408423
# 130              Curicica     646.448508        764.408423
# 139         Gardenia Azul     646.448508        764.408423
# 131              Botafogo    1180.675882        423.449787
# 135                  Anil     646.448508        764.408423
# 137               Camorim    1167.358492        644.473336
# 138               Humaita    1180.675882        423.449787
# 141        Vargem Pequena    1167.358492        644.473336
# 144                 Lagoa     777.602554        567.540861
# 151               Rocinha     777.602554        567.540861
# 148                Leblon     777.602554        567.540861
# 152    Pedra de Guaratiba     374.149360        724.667841
# 161                  Lapa    4871.753940       1730.203982
# 159               Deodoro    1422.348026        630.102144
# 160              Gericino    1422.348026        630.102144
# 3               Bancarios     506.370607        528.446144
# 143                  Leme     809.532657        805.917270
# 20                 Centro    3306.226945       3306.226945
# 71                Colegio    2130.128209       2130.128209
# 23                 Tijuca    1432.398603       1432.398603
#
# [161 rows x 3 columns]

# %% [markdown]
# # Salvar variáveis sócio economicas no banco de dados.

# %%
# Salvar variáveis de bairros no banco de dados
b = z.pd.merge(b,df,on=['nome'], how='left')
b
# Out:
#      gid                  nome  viz_anos_estudo  viz_perc_alf  viz_renda  \
# 0      1               Paqueta         7.590000     94.980000    1707.33
# 1      4                Galeao         7.170000     95.580000    1369.61
# 2      8          Campo Grande         7.630000     97.480000    1361.81
# 3     15      Jardim Guanabara        11.710000     99.120000    3565.49
# 4     25          Pitangueiras         7.010000     95.330000    1279.72
# 5     20                 Bangu         6.950000     97.240000    1087.77
# 6     33       Parque Anchieta         7.670000     98.110000    1310.80
# 7     28                 Penha         7.520000     97.110000    1202.96
# 8     30               Ribeira        10.880000     99.270000    2652.63
# 9     41                  Mare         4.930000     91.950000     757.19
# 10    42          Vila Militar         8.540000     97.880000    1659.14
# 11    46              Realengo         7.200000     97.280000    1149.50
# 12    43  Cidade Universitaria         7.770000     97.480000    1414.58
# 13    50             Paciencia         6.210000     95.730000     885.86
# 14    53              Vaz Lobo         7.920000     98.450000    1125.68
# 15    63            Santa Cruz         6.150000     95.580000     941.49
# 16    67     Campo dos Afonsos        12.110000    100.000000    3738.81
# 17    70       Engenheiro Leal         6.870000     97.270000    1058.06
# 18    79              Campinho         8.580000     97.680000    1741.28
# 19    90              Inhoaiba         6.140000     95.490000     914.03
# 20    98                Centro         8.960000     98.500000    1817.85
# 21   106               Taquara         8.740000     97.810000    1769.21
# 22   116          Santa Teresa         8.660000     98.030000    1697.49
# 23   118                Tijuca        11.280000     98.800000    3357.40
# 24   124              Flamengo        12.500000     99.480000    4662.41
# 25   127         Vargem Grande         5.860000     94.280000    1455.82
# 26   128     Alto da Boa Vista         8.460000     97.170000    2094.09
# 27   126             Guaratiba         5.630000     93.830000     939.00
# 28   134              Sepetiba         6.890000     96.030000     940.14
# 29   140       Jardim Botanico        12.730000     99.570000    5810.82
# ..   ...                   ...              ...           ...        ...
# 131  110           Cidade Nova         7.260000     96.210000    1344.19
# 132  112           Vila Isabel        10.450000     97.510000    2501.98
# 133  113              Maracana        12.170000     99.240000    3452.86
# 134  114                Gloria        10.810000     98.950000    2872.89
# 135  115          Rio Comprido         8.810000     96.800000    1547.99
# 136  117               Estacio         7.420000     96.780000    1273.79
# 137  119               Catumbi         6.660000     95.600000    1070.35
# 138  120                Grajau        11.420000     98.320000    2987.24
# 139  121             Pechincha        10.430000     98.880000    2464.69
# 140  122               Andarai        10.710000     98.130000    2505.37
# 141  123                Catete         9.880000     98.410000    2946.75
# 142  125           Laranjeiras        12.700000     99.290000    4574.06
# 143  129           Cosme Velho        10.840000     97.370000    4172.80
# 144  133        Cidade de Deus         5.930000     95.560000     823.44
# 145  130              Curicica         7.300000     97.510000    1270.53
# 146  139         Gardenia Azul         5.540000     95.140000    1069.06
# 147  131              Botafogo        11.770000     99.150000    4269.21
# 148  135                  Anil         9.810000     98.430000    2554.59
# 149  137               Camorim         5.660000     96.860000    2260.63
# 150  138               Humaita        13.110000     99.690000    4856.16
# 151  141        Vargem Pequena         5.630000     93.860000    1273.29
# 152  144                 Lagoa        13.890000     99.640000    8286.46
# 153  151               Rocinha         4.590000     93.420000     747.42
# 154  148                Leblon        12.670000     99.540000    6844.63
# 155  152    Pedra de Guaratiba         7.410000     97.100000    1363.78
# 156  161                  Lapa         9.476667     98.493333    2129.41
# 157  159               Deodoro         7.060000     97.770000    1075.66
# 158  160              Gericino         7.110000     95.140000     702.44
# 159    3             Bancarios         7.760000     96.630000    1397.40
# 160  143                  Leme        12.060000     97.120000    4388.39
#
#      viz_sanea   viz_idh  viz_crm_roubo  viz_crm_violento
# 0     0.984702  0.822264    4871.753940       1730.203982
# 1     0.910094  0.777761     506.370607        528.446144
# 2     0.811100  0.809680     548.152777        750.171811
# 3     0.989630  0.963001     506.370607        528.446144
# 4     0.995078  0.858446     506.370607        528.446144
# 5     0.930159  0.794029    1422.348026        630.102144
# 6     0.940510  0.832555    2138.462156        538.945453
# 7     0.977766  0.804251    1247.621093        539.180020
# 8     0.991115  0.859195     506.370607        528.446144
# 9     0.972749  0.721584    1005.882404        548.783181
# 10    0.732883  0.856453    1422.348026        630.102144
# 11    0.911475  0.802987    1422.348026        630.102144
# 12    0.700441  0.777761     506.370607        528.446144
# 13    0.825768  0.751201     374.149360        724.667841
# 14    0.972583  0.807040    2121.794262        724.358959
# 15    0.761972  0.741684     374.149360        724.667841
# 16    0.997333  0.856453    1422.348026        630.102144
# 17    0.852363  0.807040    2121.794262        724.358959
# 18    0.921512  0.903979    2121.794262        724.358959
# 19    0.879939  0.747347     548.152777        750.171811
# 20    0.998841  0.894300    3306.226945       3306.226945
# 21    0.868292  0.876299     646.448508        764.408423
# 22    0.984823  0.877972    4871.753940       1730.203982
# 23    0.977674  0.925903    1432.398603       1432.398603
# 24    0.999221  0.959021    1180.675882        423.449787
# 25    0.296900  0.745803    1167.358492        644.473336
# 26    0.663968  0.925903    1124.097257        588.673608
# 27    0.516760  0.743630     374.149360        724.667841
# 28    0.692165  0.760694     374.149360        724.667841
# 29    0.997993  0.957384     777.602554        567.540861
# ..         ...       ...            ...               ...
# 131   0.990868  0.866775    1740.699949        715.936741
# 132   0.995027  0.900922    1124.097257        588.673608
# 133   0.998151  0.943927    1740.699949        715.936741
# 134   0.999774  0.940172    1180.675882        423.449787
# 135   0.963885  0.849288    1740.699949        715.936741
# 136   0.954167  0.828924    1740.699949        715.936741
# 137   0.971142  0.801654    1740.699949        715.936741
# 138   0.986873  0.937881    1124.097257        588.673608
# 139   0.882548  0.900158     646.448508        764.408423
# 140   0.979031  0.909303    1124.097257        588.673608
# 141   0.995494  0.901333    1180.675882        423.449787
# 142   0.999086  0.957436    1180.675882        423.449787
# 143   0.990602  0.877972    1180.675882        423.449787
# 144   0.971578  0.750615     646.448508        764.408423
# 145   0.844127  0.828319     646.448508        764.408423
# 146   0.881188  0.767757     646.448508        764.408423
# 147   0.995697  0.952152    1180.675882        423.449787
# 148   0.767546  0.911022     646.448508        764.408423
# 149   0.373228  0.745803    1167.358492        644.473336
# 150   0.999139  0.959008    1180.675882        423.449787
# 151   0.691088  0.745803    1167.358492        644.473336
# 152   0.999399  0.959423     777.602554        567.540861
# 153   0.856901  0.732113     777.602554        567.540861
# 154   0.998769  0.967067     777.602554        567.540861
# 155   0.842857  0.743630     374.149360        724.667841
# 156   0.994479  0.904148    4871.753940       1730.203982
# 157   0.912938  0.856453    1422.348026        630.102144
# 158   0.939597  0.800463    1422.348026        630.102144
# 159   0.985287  0.860875     506.370607        528.446144
# 160   0.991317  0.955413     809.532657        805.917270
#
# [161 rows x 9 columns]

# %%
reload(z.d)
#b.index = b.gid
#del b['gid']
z.d.salva_dataframe(b, '_var_socioecon')
# Out:
# /Users/sergio/Library/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/sqlalchemy/dialects/postgresql/base.py:2079: SAWarning: Did not recognize type 'geometry' of column 'geom'
#   name, format_type, default, notnull, domains, enums, schema)
