# %%
# %pylab inline

import zap_util as z

import statsmodels.api as sm
import statsmodels.formula.api as smf
rmse = {}
z.set_style()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = z.get_imoveis_dataframe(False)

# %%
df2 = df[df.bairro_g == 'Barra da Tijuca']
var_ignore = ['bairro_g']
f,_,e = z.prep_formula(df2,'df2', cat=['suites','quartos','garagem'],ignore=var_ignore)
print('Variáveis excluídas: ' + ','.join(e))
print( '\n')
print('Fórmula: '+ f)
# Out:
# Variáveis excluídas: id_bairro_g,bairro_g,preco,m2
#
#
# Fórmula: df2.preco  ~ df2.dm_esquina + C(df2.quartos) + df2.dm_closet + df2.dist_saude_privada + df2.dm_armario + df2.se_anos_estudo + df2.dm_recuado + df2.dm_fundos + df2.dm_andar_alto + df2.dm_mezanino + df2.dm_piscina + df2.dm_playground + df2.dist_centro_lng + df2.dm_hidrometro + df2.lng + df2.dm_seguranca + df2.dist_trem + df2.dist_lagoa + C(df2.suites) + df2.dm_sol_da_manha + df2.area + df2.dm_frente + df2.dist_delegacia + df2.dist_centro_lat + df2.dm_blindex + df2.dist_favela + df2.dist_logradouro + df2.dm_terraco + df2.dm_salao_de_jogos + df2.se_idh + df2.dist_centro + df2.dm_sala_de_jantar + df2.dm_dependencia + df2.se_crm_violento + df2.dm_estacionamento_visitantes + df2.dm_banheira + df2.dist_saude_publica + df2.dist_bombeiro + df2.dm_jardim + C(df2.garagem) + df2.dist_praia + df2.dm_duplex + df2.dm_andar_inteiro + df2.dm_sol_da_tarde + df2.condominio + df2.lat + df2.dm_varanda + df2.dm_triplex + df2.dm_children_care + df2.dm_quarto_de_empregada + df2.se_renda + df2.dm_andar_baixo + df2.dm_lateral_ + df2.dm_portaria + df2.dm_indevassavel + df2.dm_cobertura + df2.dm_copa + df2.se_perc_alfabetizacao + df2.dm_quadra + df2.dm_elevador_privativo + df2.dm_sauna + df2.dm_salao_de_festas + df2.se_saneamento + df2.se_crm_roubo + df2.dist_metro + df2.dm_churrasqueira + df2.dm_linear

# %%
lm = sm.formula.ols(f, df2).fit()
rmse['default'] = z.rmse(lm.resid)
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              df2.preco   R-squared:                       0.808
# Model:                            OLS   Adj. R-squared:                  0.806
# Method:                 Least Squares   F-statistic:                     383.1
# Date:                Sat, 04 Apr 2015   Prob (F-statistic):               0.00
# Time:                        18:10:14   Log-Likelihood:                -45019.
# No. Observations:                6262   AIC:                         9.018e+04
# Df Residuals:                    6193   BIC:                         9.064e+04
# Df Model:                          68
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# Intercept                         1.783e+05   3.16e+07      0.006      0.996     -6.18e+07  6.22e+07
# C(df2.quartos)[T.2]                 96.5502     19.956      4.838      0.000        57.430   135.670
# C(df2.quartos)[T.3]                114.3591     22.551      5.071      0.000        70.151   158.567
# C(df2.quartos)[T.4]                199.9828     25.386      7.878      0.000       150.218   249.747
# C(df2.suites)[T.1.0]                15.1336     15.754      0.961      0.337       -15.750    46.017
# C(df2.suites)[T.2.0]                -5.1738     19.249     -0.269      0.788       -42.908    32.561
# C(df2.suites)[T.3.0]                40.9971     23.206      1.767      0.077        -4.495    86.489
-27. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
z.plot_residual(lm)

# %%
z.print_autocorr(df,['id_bairro_g'])
# Out:
# Coluna               | Autocorrelacionada com
# se_anos_estudo       : ['se_idh(0.95)', 'se_renda(0.87)', 'se_perc_alfabetizacao(0.89)']
# dm_frente            : ['dm_varanda(0.70)', 'dm_salao_de_festas(0.73)']
# dist_delegacia       : ['dist_centro(0.82)', 'dist_metro(0.87)']
# dist_centro_lng      : ['lng(-1.00)', 'dist_delegacia(0.79)', 'dist_centro(0.97)', 'se_saneamento(-0.80)', 'dist_metro(0.92)']
# preco                : ['area(0.71)', 'm2(0.71)']
# se_saneamento        : ['dist_metro(-0.79)']
# lng                  : ['dist_delegacia(-0.79)', 'dist_centro(-0.97)', 'se_saneamento(0.80)', 'dist_metro(-0.92)']
# dist_centro          : ['se_saneamento(-0.79)', 'dist_metro(0.96)']
# se_idh               : ['se_renda(0.77)', 'se_perc_alfabetizacao(0.89)']
# dist_trem            : ['dist_delegacia(0.74)', 'dist_centro_lat(0.91)', 'dist_centro(0.71)', 'lat(-0.80)', 'dist_metro(0.79)']
# dist_lagoa           : ['lat(0.91)']

# %%
var_ignore += ['id_bairro_g', 'se_anos_estudo','dm_piscina', 'dist_lagoa', 
    'dm_frente','dist_centro_lat','dist_centro_lng','dist_delegacia',
    'se_idh','preco','m2','dist_metro','dist_trem','dist_centro',
    'se_saneamento',]
z.print_autocorr(df, var_ignore)
# Out:
# Não há colunas autocorrelacionadas.

# %%
f,_,e = z.prep_formula(df2,'df2', cat=['suites','quartos','garagem'],ignore=var_ignore)
print('Variáveis excluídas: ' + ','.join(e))
print( '\n')
print('Fórmula: '+ f)
# Out:
# Variáveis excluídas: se_anos_estudo,preco,dm_piscina,bairro_g,dist_centro_lat,dist_trem,dist_lagoa,dm_frente,dist_delegacia,dist_centro_lng,m2,id_bairro_g,se_saneamento,se_idh,dist_centro,dist_metro
#
#
# Fórmula: df2.preco  ~ df2.dm_esquina + C(df2.quartos) + df2.dm_closet + C(df2.suites) + df2.dm_armario + df2.se_crm_violento + df2.dm_recuado + df2.dm_fundos + df2.dm_andar_alto + df2.dm_mezanino + df2.dm_playground + df2.dm_hidrometro + df2.lng + df2.dm_seguranca + df2.se_renda + df2.dm_sol_da_manha + df2.area + df2.dist_saude_privada + df2.dm_linear + df2.dm_blindex + df2.dist_favela + df2.dist_logradouro + df2.dm_terraco + df2.dm_salao_de_jogos + df2.dm_andar_inteiro + df2.dm_sala_de_jantar + df2.dm_dependencia + df2.dm_estacionamento_visitantes + df2.dm_banheira + df2.dist_saude_publica + df2.dist_bombeiro + df2.dm_jardim + C(df2.garagem) + df2.dist_praia + df2.dm_duplex + df2.dm_sol_da_tarde + df2.condominio + df2.lat + df2.dm_varanda + df2.dm_triplex + df2.dm_children_care + df2.dm_quarto_de_empregada + df2.dm_andar_baixo + df2.dm_lateral_ + df2.dm_portaria + df2.dm_indevassavel + df2.dm_cobertura + df2.dm_copa + df2.se_perc_alfabetizacao + df2.dm_quadra + df2.dm_elevador_privativo + df2.dm_sauna + df2.dm_salao_de_festas + df2.se_crm_roubo + df2.dm_churrasqueira

# %%
lm = sm.formula.ols(f, df2).fit()
rmse['w_autocorr'] = z.rmse(lm.resid)
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:
# df2.dm_andar_inteiro                13.9789     14.302      0.977      0.328       -14.058    42.016
# df2.dm_sala_de_jantar             -267.0303    329.547     -0.810      0.418      -913.057   378.997
# df2.dm_dependencia                 -35.2377     17.327     -2.034      0.042       -69.204    -1.272
# df2.dm_estacionamento_visitantes  -107.3555     35.982     -2.984      0.003      -177.893   -36.818
# df2.dm_banheira                    -14.2694     13.138     -1.086      0.277       -40.025    11.486
# df2.dist_saude_publica              31.5298      9.144      3.448      0.001        13.604    49.456
# df2.dist_bombeiro                   44.3262      6.982      6.349      0.000        30.640    58.013
# df2.dm_jardim                      -30.5951     15.040     -2.034      0.042       -60.079    -1.111
# df2.dist_praia                    -124.9595     68.746     -1.818      0.069      -259.725     9.806
# df2.dm_duplex                       58.0144     35.822      1.619      0.105       -12.210   128.239
# df2.dm_sol_da_tarde               -129.6358    234.703     -0.552      0.581      -589.734   330.463
# df2.condominio                     -33.7521      8.828     -3.823      0.000       -51.058   -16.446
# df2.lat                           5431.4598   6620.800      0.820      0.412     -7547.603  1.84e+04
# df2.dm_varanda                     -35.7828     12.220     -2.928      0.003       -59.738   -11.828
# df2.dm_triplex                      11.5260     86.843      0.133      0.894      -158.716   181.768
# df2.dm_children_care               -13.1033     17.328     -0.756      0.450       -47.072    20.865
# df2.dm_quarto_de_empregada          76.6712     13.838      5.541      0.000        49.544   103.798
# df2.dm_andar_baixo                 -22.8077     22.939     -0.994      0.320       -67.776    22.160
# df2.dm_lateral_                    -40.1122     18.221     -2.201      0.028       -75.832    -4.392
# df2.dm_portaria                     -7.5594     14.816     -0.510      0.610       -36.603    21.484
# df2.dm_indevassavel                -33.0079     23.041     -1.433      0.152       -78.177    12.161
# df2.dm_cobertura                   -13.0660     69.333     -0.188      0.851      -148.983   122.851
# df2.dm_copa                        203.1576     68.664      2.959      0.003        68.553   337.762
# df2.se_perc_alfabetizacao        -6.531e+08   1.44e+10     -0.045      0.964     -2.88e+10  2.75e+10
# df2.dm_quadra                        3.3539     14.237      0.236      0.814       -24.555    31.263
# df2.dm_elevador_privativo           17.1257     14.830      1.155      0.248       -11.947    46.198
# df2.dm_sauna                        31.3027     27.191      1.151      0.250       -22.002    84.607
# df2.dm_salao_de_festas              13.0423     13.598      0.959      0.338       -13.615    39.699
# df2.se_crm_roubo                  2.804e+09   6.18e+10      0.045      0.964     -1.18e+11  1.24e+11
# df2.dm_churrasqueira                 9.6934     10.564      0.918      0.359       -11.016    30.403
# ==============================================================================
# Omnibus:                     3512.283   Durbin-Watson:                   1.982
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75892.545
# Skew:                           2.238   Prob(JB):                         0.00
# Kurtosis:                      19.457   Cond. No.                     5.32e+18
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.07e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %%
# Lista de parâmetros sem significância.
plow = lm.pvalues.copy()
#bp.index = [i.replace('C(df.bairro_g)[T.', '').replace(']','')  for i in bp.index.tolist()]
c = plow > 0.05
plow = plow[c]
plow
# Out:
# Intercept                    0.963780
# C(df2.suites)[T.1.0]         0.180388
# C(df2.suites)[T.2.0]         0.450291
# C(df2.suites)[T.3.0]         0.252257
# C(df2.garagem)[T.1.0]        0.127878
# C(df2.garagem)[T.2.0]        0.336370
# df2.dm_esquina               0.850225
# df2.se_crm_violento          0.963780
# df2.dm_recuado               0.824947
# df2.dm_fundos                0.506379
# df2.dm_andar_alto            0.873103
# df2.dm_mezanino              0.926653
# df2.dm_playground            0.176523
# df2.dm_seguranca             0.271545
# df2.se_renda                 0.963780
# df2.dm_sol_da_manha          0.747259
# df2.dm_linear                0.290823
# df2.dm_blindex               0.524058
# df2.dist_favela              0.777358
# df2.dm_salao_de_jogos        0.884305
# df2.dm_andar_inteiro         0.328409
# df2.dm_sala_de_jantar        0.417802
# df2.dm_banheira              0.277485
# df2.dist_praia               0.069158
# df2.dm_duplex                0.105391
# df2.dm_sol_da_tarde          0.580735
# df2.lat                      0.412041
# df2.dm_triplex               0.894417
# df2.dm_children_care         0.449555
# df2.dm_andar_baixo           0.320123
# df2.dm_portaria              0.609907
# df2.dm_indevassavel          0.152039
# df2.dm_cobertura             0.850528
# df2.se_perc_alfabetizacao    0.963780
# df2.dm_quadra                0.813763
# df2.dm_elevador_privativo    0.248222
# df2.dm_sauna                 0.249693
# df2.dm_salao_de_festas       0.337536
# df2.se_crm_roubo             0.963780
# df2.dm_churrasqueira         0.358882
# dtype: float64

# %%
# Remover parâmetros sem significância.
var_ignore_too = map(lambda x: x.replace('df2.',''), plow.index.tolist())
var_ignore += var_ignore_too

# %%
z.print_autocorr(df, var_ignore)
# Out:
# Não há colunas autocorrelacionadas.

# %%
f,_,e = z.prep_formula(df2,'df2', cat=['suites','quartos','garagem'],ignore=var_ignore)
print('Variáveis excluídas: ' + ','.join(e))
print( '\n')
print('Fórmula: '+ f)
# Out:
# Variáveis excluídas: dm_churrasqueira,se_anos_estudo,dm_recuado,dm_fundos,dm_andar_alto,preco,dm_piscina,dm_playground,dm_mezanino,dm_seguranca,dist_trem,dist_lagoa,C(suites)[T.2.0],dm_frente,dist_delegacia,dm_blindex,dist_favela,Intercept,m2,id_bairro_g,bairro_g,se_idh,dm_children_care,dm_sala_de_jantar,se_crm_violento,dm_esquina,dm_banheira,dm_andar_inteiro,C(suites)[T.1.0],C(suites)[T.3.0],dm_duplex,dm_sol_da_tarde,se_renda,lat,dm_elevador_privativo,dist_centro_lat,dm_triplex,se_crm_roubo,dm_indevassavel,C(garagem)[T.2.0],dist_centro,dm_portaria,dm_cobertura,C(garagem)[T.1.0],dist_praia,dist_centro_lng,dm_quadra,dm_salao_de_jogos,dm_sauna,dm_salao_de_festas,se_perc_alfabetizacao,se_saneamento,dm_andar_baixo,dist_metro,dm_sol_da_manha,dm_linear
#
#
# Fórmula: df2.preco  ~ C(df2.suites) + df2.dm_dependencia + C(df2.quartos) + df2.dm_closet + df2.dm_estacionamento_visitantes + df2.dist_saude_privada + df2.dm_armario + df2.dist_saude_publica + df2.area + df2.dm_copa + df2.dist_bombeiro + df2.dm_jardim + C(df2.garagem) + df2.dist_logradouro + df2.dm_quarto_de_empregada + df2.condominio + df2.dm_hidrometro + df2.lng + df2.dm_varanda + df2.dm_terraco + df2.dm_lateral_

# %%
lm = sm.formula.ols(f, df2).fit()
rmse['w_unsignif_1'] = z.rmse(lm.resid)
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              df2.preco   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     836.6
# Date:                Sat, 04 Apr 2015   Prob (F-statistic):               0.00
# Time:                        18:10:29   Log-Likelihood:                -45214.
# No. Observations:                6262   AIC:                         9.049e+04
# Df Residuals:                    6232   BIC:                         9.069e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# Intercept                         1.771e+05   7577.546     23.368      0.000      1.62e+05  1.92e+05
# C(df2.suites)[T.1.0]                22.7790     15.787      1.443      0.149        -8.168    53.726
# C(df2.suites)[T.2.0]               -19.3459     19.429     -0.996      0.319       -57.433    18.741
# C(df2.suites)[T.3.0]                21.5207     23.312      0.923      0.356       -24.180    67.221
# C(df2.suites)[T.4.0]               215.5220     29.184      7.385      0.000       158.312   272.732
# C(df2.quartos)[T.2]                 59.7843     20.123      2.971      0.003        20.337    99.231
# C(df2.quartos)[T.3]                 68.4161     22.624      3.024      0.003        24.066   112.766
# C(df2.quartos)[T.4]                151.0797     25.524      5.919      0.000       101.043   201.116
# C(df2.garagem)[T.1.0]              -37.8501     25.015     -1.513      0.130       -86.888    11.188
# C(df2.garagem)[T.2.0]               29.5344     24.663      1.198      0.231       -18.814    77.882
# C(df2.garagem)[T.3.0]              172.2487     27.702      6.218      0.000       117.943   226.554
# C(df2.garagem)[T.4.0]              479.6392     45.295     10.589      0.000       390.845   568.434
# df2.dm_dependencia                 -45.9400     16.635     -2.762      0.006       -78.551   -13.329
# df2.dm_closet                      -29.0356     13.189     -2.201      0.028       -54.891    -3.180
# df2.dm_estacionamento_visitantes   -80.6165     34.032     -2.369      0.018      -147.332   -13.901
# df2.dist_saude_privada             131.8126     17.991      7.327      0.000        96.544   167.081
# df2.dm_armario                      26.1682      9.453      2.768      0.006         7.636    44.700
# df2.dist_saude_publica              80.7060      5.496     14.683      0.000        69.931    91.481
# df2.area                             9.0113      0.132     68.199      0.000         8.752     9.270
# df2.dm_copa                        164.6708     68.274      2.412      0.016        30.830   298.512
# df2.dist_bombeiro                   43.4912      5.272      8.249      0.000        33.156    53.827
# df2.dm_jardim                      -19.7776     13.298     -1.487      0.137       -45.846     6.291
# df2.dist_logradouro                194.9598     12.004     16.242      0.000       171.428   218.491
# df2.dm_quarto_de_empregada          81.0002     13.570      5.969      0.000        54.399   107.601
# df2.condominio                     -28.8829      8.748     -3.302      0.001       -46.032   -11.734
# df2.dm_hidrometro                  181.4258     16.935     10.713      0.000       148.228   214.624
# df2.lng                           4090.9416    175.007     23.376      0.000      3747.868  4434.016
# df2.dm_varanda                     -25.7119     10.259     -2.506      0.012       -45.824    -5.600
# df2.dm_terraco                    -173.1133     29.304     -5.908      0.000      -230.559  -115.668
# df2.dm_lateral_                    -39.7159     15.960     -2.489      0.013       -71.002    -8.430
# ==============================================================================
# Omnibus:                     3521.914   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75275.862
# Skew:                           2.251   Prob(JB):                         0.00
# Kurtosis:                      19.378   Cond. No.                     2.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# Lista de parâmetros sem significância.
plow = lm.pvalues.copy()
c = plow > 0.05
plow = plow[c]
plow
# Out:
# C(df2.suites)[T.1.0]     0.149091
# C(df2.suites)[T.2.0]     0.319414
# C(df2.suites)[T.3.0]     0.355969
# C(df2.garagem)[T.1.0]    0.130305
# C(df2.garagem)[T.2.0]    0.231150
# df2.dm_jardim            0.136996
# dtype: float64

# %%
# Remover parâmetros sem significância.

# Encontrar variáveis que não são bairros.
var_ignore_too = map(lambda x: x.replace('df.',''), plow.index.tolist())
var_ignore_too = var_ignore_too[1:]
var_ignore += var_ignore_too

# %%
f,_,e = z.prep_formula(df2,'df2', cat=['bairro_g','suites','quartos','garagem'],ignore=var_ignore)
print('Variáveis excluídas: ' + ','.join(e))
print( '\n')
print('Fórmula: '+ f)
# Out:
# Variáveis excluídas: se_crm_violento,C(df2.suites)[T.3.0],dm_sol_da_tarde,dm_playground,dm_mezanino,C(df2.garagem)[T.2.0],C(suites)[T.2.0],dm_frente,dist_delegacia,m2,C(suites)[T.1.0],dm_children_care,dm_churrasqueira,df2.dm_jardim,dm_salao_de_jogos,C(suites)[T.3.0],se_renda,se_crm_roubo,dm_indevassavel,dist_centro,C(garagem)[T.1.0],se_perc_alfabetizacao,dm_quadra,dm_sauna,dm_salao_de_festas,dm_andar_baixo,dm_sol_da_manha,C(garagem)[T.2.0],se_anos_estudo,dm_recuado,dm_fundos,dm_andar_alto,preco,dm_piscina,C(df2.garagem)[T.1.0],dm_seguranca,dist_trem,dist_lagoa,dm_banheira,dm_linear,dm_blindex,dist_favela,Intercept,id_bairro_g,bairro_g,se_idh,dm_sala_de_jantar,C(df2.suites)[T.2.0],dm_duplex,lat,dist_centro_lat,dm_triplex,dm_andar_inteiro,dm_portaria,dm_cobertura,dist_praia,dist_centro_lng,dm_esquina,se_saneamento,dist_metro,dm_elevador_privativo
#
#
# Fórmula: df2.preco  ~ C(df2.suites) + df2.dm_dependencia + C(df2.quartos) + df2.dm_closet + df2.dm_estacionamento_visitantes + df2.dist_saude_privada + df2.dm_armario + df2.dist_saude_publica + df2.area + df2.dm_copa + df2.dist_bombeiro + df2.dm_jardim + C(df2.garagem) + df2.dist_logradouro + df2.dm_quarto_de_empregada + df2.condominio + df2.dm_hidrometro + df2.lng + df2.dm_varanda + df2.dm_terraco + df2.dm_lateral_

# %%
lm = sm.formula.ols(f, df2).fit()
rmse['w_unsignif_2'] = z.rmse(lm.resid)
print(lm.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:              df2.preco   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     836.6
# Date:                Sat, 04 Apr 2015   Prob (F-statistic):               0.00
# Time:                        18:10:32   Log-Likelihood:                -45214.
# No. Observations:                6262   AIC:                         9.049e+04
# Df Residuals:                    6232   BIC:                         9.069e+04
# Df Model:                          29
# Covariance Type:            nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [95.0% Conf. Int.]
# ----------------------------------------------------------------------------------------------------
# Intercept                         1.771e+05   7577.546     23.368      0.000      1.62e+05  1.92e+05
# C(df2.suites)[T.1.0]                22.7790     15.787      1.443      0.149        -8.168    53.726
# C(df2.suites)[T.2.0]               -19.3459     19.429     -0.996      0.319       -57.433    18.741
# C(df2.suites)[T.3.0]                21.5207     23.312      0.923      0.356       -24.180    67.221
# C(df2.suites)[T.4.0]               215.5220     29.184      7.385      0.000       158.312   272.732
# C(df2.quartos)[T.2]                 59.7843     20.123      2.971      0.003        20.337    99.231
# C(df2.quartos)[T.3]                 68.4161     22.624      3.024      0.003        24.066   112.766
# C(df2.quartos)[T.4]                151.0797     25.524      5.919      0.000       101.043   201.116
# C(df2.garagem)[T.1.0]              -37.8501     25.015     -1.513      0.130       -86.888    11.188
# C(df2.garagem)[T.2.0]               29.5344     24.663      1.198      0.231       -18.814    77.882
# C(df2.garagem)[T.3.0]              172.2487     27.702      6.218      0.000       117.943   226.554
# C(df2.garagem)[T.4.0]              479.6392     45.295     10.589      0.000       390.845   568.434
# df2.dm_dependencia                 -45.9400     16.635     -2.762      0.006       -78.551   -13.329
# df2.dm_closet                      -29.0356     13.189     -2.201      0.028       -54.891    -3.180
# df2.dm_estacionamento_visitantes   -80.6165     34.032     -2.369      0.018      -147.332   -13.901
# df2.dist_saude_privada             131.8126     17.991      7.327      0.000        96.544   167.081
# df2.dm_armario                      26.1682      9.453      2.768      0.006         7.636    44.700
# df2.dist_saude_publica              80.7060      5.496     14.683      0.000        69.931    91.481
# df2.area                             9.0113      0.132     68.199      0.000         8.752     9.270
# df2.dm_copa                        164.6708     68.274      2.412      0.016        30.830   298.512
# df2.dist_bombeiro                   43.4912      5.272      8.249      0.000        33.156    53.827
# df2.dm_jardim                      -19.7776     13.298     -1.487      0.137       -45.846     6.291
# df2.dist_logradouro                194.9598     12.004     16.242      0.000       171.428   218.491
# df2.dm_quarto_de_empregada          81.0002     13.570      5.969      0.000        54.399   107.601
# df2.condominio                     -28.8829      8.748     -3.302      0.001       -46.032   -11.734
# df2.dm_hidrometro                  181.4258     16.935     10.713      0.000       148.228   214.624
# df2.lng                           4090.9416    175.007     23.376      0.000      3747.868  4434.016
# df2.dm_varanda                     -25.7119     10.259     -2.506      0.012       -45.824    -5.600
# df2.dm_terraco                    -173.1133     29.304     -5.908      0.000      -230.559  -115.668
# df2.dm_lateral_                    -39.7159     15.960     -2.489      0.013       -71.002    -8.430
# ==============================================================================
# Omnibus:                     3521.914   Durbin-Watson:                   1.992
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            75275.862
# Skew:                           2.251   Prob(JB):                         0.00
# Kurtosis:                      19.378   Cond. No.                     2.58e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.58e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# # Determinar se a Regresssão média simples é o melhor método.

# %%
modelo_rl = z.rmse(lm.resid)
modelo_media = z.rmse(df2.preco-df2.preco.mean())
if modelo_rl < modelo_media :
    print 'REGRESSAO WINS por {:.2f}%'.format((1-modelo_rl/modelo_media)*100)
else:
    print 'MEDIA WINS por {:.2f}%'.format((1-modelo_media/modelo_ml)*100)
# Out:
# REGRESSAO WINS por 54.79%

# %%
 modelo_rl , modelo_media
# Out:
# (330.75201194290781, 731.63818866598865)

# %%
srmse = z.pd.Series(data=rmse.values(),index=rmse.keys())
srmse.sort(ascending=False)
srmse.plot(kind='barh');
