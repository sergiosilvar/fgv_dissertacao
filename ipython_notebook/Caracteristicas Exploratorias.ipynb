# %%
# %pylab inline

import zap_util as z
import re
reload(z)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'zap_util' from 'zap_util.pyc'>

# %%
df = z.get('select id, det_imovel,carac_imovel, carac_condo from imovel where carac_imovel is not null or carac_condo is not null or det_imovel is not null')
df.describe()
# Out:
#                                                det_imovel carac_imovel  \
# count                                               64555        77414
# unique                                              63054        46571
# top     dormitórios:3 quartos/dts\nsuítes:3 suítes\nva...    Interfone
# freq                                                    6         1700
#
#        carac_condo
# count        41449
# unique        6815
# top        Varanda
# freq          3652

# %%
# Tratar NAs.
df.fillna('',inplace=True)

# Converter todos os textos para minúsculo.
df['carac_condo'] = df.carac_condo.apply(str.lower)
df['carac_imovel'] = df.carac_imovel.apply(str.lower)
df['det_imovel'] = df.det_imovel.apply(str.lower)
df['carac'] = df.carac_imovel+'\n'+df.carac_condo+df.det_imovel
del df['carac_condo'], df['carac_imovel'], df['det_imovel']

# %%
# Remover acentos.
troca = []
troca.append( {'de':['á','â','ã','ä','à','Á','Â','Ã','Ä','À'], 'para':'a'})
troca.append( {'de':['é','ê','ë','è','É','Ê','Ë','È'], 'para':'e'})
troca.append( {'de':['í','î','ï','ì','Í','Î','Ï','Ì'], 'para':'i'})
troca.append( {'de':['ó','ô','ö','õ','ò','Ó','Ô','Ö','Õ','Ò'], 'para':'o'})
troca.append( {'de':['ú','û','ü','ù','Ú','Û','Ü','Ù'], 'para':'u'})
troca.append( {'de':['ç','Ç'], 'para':'c'})

for item in troca:
    for c in item['de']:
        df.carac = df.carac.str.replace(c,item['para'], case=False)

# %%
# DataFrame para as características.
dfc = z.pd.DataFrame(index=df.index)

def caract(nome):
    dfc[nome] = df.carac.str.contains(nome)


features = [
'alto',
'andar inteiro',
'armario',
'banheira',
'blindex',
'children care',
'churrasqueira',
'closet',
'cobertura',
'copa',
'dependencia',
'duplex',
'elevador privativo',
'esquina',
'estacionamento visitantes',
'frente',
'fundos',
'heliponto',
'hidrometro',
'hidromassagem',
'jardim',
'lareira',
'linear',
'mezanino',
'piscina',
'playground',
'portaria',
'quadra',
'quarto de empregada',
'recuado',
'sala de jantar',
'salao de festas',
'salao de jogos',
'sauna',
'sauna',
'seguranca',
'sol da manha',
'sol da tarde',
'terraco',
'triplex',
'varanda',
'indevassavel'
]

for f in features:
    caract(f)

dfc.describe()
# Out:
#              alto andar inteiro    armario     banheira     blindex  \
# count       91090         91090      91090        91090       91090
# mean   0.04598748    0.01533648   0.376375  0.004533977  0.08815457
# std     0.2094591     0.1228879  0.4844785   0.06718236   0.2835211
# min         False         False      False        False       False
# 25%             0             0          0            0           0
# 50%             0             0          0            0           0
# 75%             0             0          1            0           0
# max          True          True       True         True        True
#
#       children care churrasqueira      closet   cobertura       copa  \
# count         91090         91090       91090       91090      91090
# mean     0.04101438     0.2470853  0.08259963  0.05023603  0.1823581
# std       0.1983246     0.4313191   0.2752776   0.2184328  0.3861415
# min           False         False       False       False      False
# 25%               0             0           0           0          0
# 50%               0             0           0           0          0
# 75%               0             0           0           0          0
# max            True          True        True        True       True
#
#           ...      salao de festas salao de jogos      sauna   seguranca  \
# count     ...                91090          91090      91090       91090
# mean      ...             0.264815      0.1073663  0.1951367  0.07204962
# std       ...            0.4412371      0.3095801  0.3963081   0.2585715
# min       ...                False          False      False       False
# 25%       ...                    0              0          0           0
# 50%       ...                    0              0          0           0
# 75%       ...                    1              0          0           0
# max       ...                 True           True       True        True
#
#       sol da manha sol da tarde     terraco      triplex    varanda  \
# count        91090        91090       91090        91090      91090
# mean    0.04616314  0.001646723  0.04238665  0.002063893   0.386925
# std      0.2098394   0.04054663   0.2014708   0.04538343  0.4870489
# min          False        False       False        False      False
# 25%              0            0           0            0          0
# 50%              0            0           0            0          0
# 75%              0            0           0            0          1
# max           True         True        True         True       True
#
#       indevassavel
# count        91090
# mean     0.0107037
# std      0.1029041
# min          False
# 25%              0
# 50%              0
# 75%              0
# max           True
#
# [8 rows x 41 columns]

# %%
# Buscar características por palavras similares.
dfc['quarto de empregada'] = dfc['quarto de empregada'] |  df.carac.str.contains('dependencia de empregada')
dfc['estacionamento visitantes'] = dfc['estacionamento visitantes'] | df.carac.str.contains('estacionamento de visitantes') | df.carac.str.contains('estacionamento para visitantes')
dfc['seguranca'] = dfc['seguranca'] | df.carac.str.contains('guarita')
dfc['indevassavel'] = dfc['indevassavel'] | df.carac.str.contains('vista livre')
dfc['sol da manha'] = dfc['sol da manha'] | df.carac.str.contains('sol manha')
dfc['sol da tarde'] = dfc['sol da tarde'] | df.carac.str.contains('sol tarde')

# A carcterística "lateral" teve que ser identificada como "lateral_" pois é palavra reservada do POSTGRESQL.
dfc['lateral_'] = df.carac.str.contains('lateral')

# %%
dfc.sum()/len(dfc)*100
# Out:
# alto                          4.598748
# andar inteiro                 1.533648
# armario                      37.637501
# banheira                      0.453398
# blindex                       8.815457
# children care                 4.101438
# churrasqueira                24.708530
# closet                        8.259963
# cobertura                     5.023603
# copa                         18.235811
# dependencia                  16.072017
# duplex                        2.919091
# elevador privativo            0.167966
# esquina                       3.040949
# estacionamento visitantes     7.563948
# frente                        6.136788
# fundos                        1.706005
# heliponto                     0.692721
# hidrometro                    0.166868
# hidromassagem                 7.170930
# jardim                        4.325392
# lareira                       0.793720
# linear                        1.172467
# mezanino                      0.468767
# piscina                      26.337688
# playground                   20.723460
# portaria                     10.744319
# quadra                       13.145241
# quarto de empregada           3.102426
# recuado                       0.313975
# sala de jantar               14.233176
# salao de festas              26.481502
# salao de jogos               10.736634
# sauna                        19.513668
# seguranca                     8.041497
# sol da manha                  5.247557
# sol da tarde                  0.173455
# terraco                       4.238665
# triplex                       0.206389
# varanda                      38.692502
# indevassavel                  4.640465
# lateral_                      1.389834
# dtype: float64

# %%
re_unid_andar = re.compile(r'(\d{1,2}) unidades por andar')
re_andares = re.compile(r'(\d{1,2}) andares')
re_elevador = re.compile(r'(\d{1,2}) elevador')
re_ano = re.compile(r'construido em (\d{2,4})')

def obtem_unid_andar(s):
    r = None
    m = re_unid_andar.search(s)
    if m:
        r = int(m.groups(0)[0])
        if r > 20:
            r = 2000+r
        if r > 14 and r < 100:
            r = 1900 + r
    return r

def obtem_andares(s):
    m = re_andares.search(s)
    if m:
        return int(m.groups(0)[0])
    return None

def obtem_elevadores(s):
    m = re_elevador.search(s)
    if m:
        return int(m.groups(0)[0])
    return None

def obtem_ano(s):
    r = None
    m = re_ano.search(s)
    if m:
        r = int(m.groups(0)[0])
        if r <= 14:
            r = 2000+r
        if r > 14 and r < 100:
            r = 1900 + r
    return r

# %%
dfc['unidades'] = df.carac.apply(obtem_unid_andar)
dfc['andar'] = df.carac.apply(obtem_andares)
dfc['elevadores'] = df.carac.apply(obtem_elevadores)
dfc['ano'] = df.carac.apply(obtem_ano)
dfc[['unidades','andar','ano']].describe()
# Out:
#            unidades         andar          ano
# count  21505.000000  61915.000000  9586.000000
# mean      43.301883      8.845352  1934.131859
# std      269.257513      5.092037   310.479165
# min        1.000000      0.000000   101.000000
# 25%        4.000000      5.000000  1967.000000
# 50%        4.000000      8.000000  1985.000000
# 75%        8.000000     12.000000  2010.000000
# max     2068.000000     80.000000  9841.000000

# %% [markdown]
# ### Tratar variável "ano".

# %%
# Copia os valores.
ano = dfc['ano']

# Remove inexistentes.
ano.dropna(inplace=True)

# Encontra quantidade de caracteres.
ano = ano.astype('int')
ano = ano.apply(str)
qtd = ano.str.len()
qtd.value_counts().index.values
# Out:
# array([4, 3], dtype=int64)

# %%
# Separa em grupo de 3 e 4 caracteres.
ano3d = ano[ano.str.len() == 3].astype('int')
ano4d = ano[ano.str.len() == 4].astype('int')

# Verificar como está o grupo de 3 caracteres.
#boxplot(ano3d)
hist(ano3d)
# Out:
# (array([ 45.,  26.,  64.,  50.,  60.,  61.,  18.,   5.,   1.,   3.]),
#  array([ 101. ,  190.2,  279.4,  368.6,  457.8,  547. ,  636.2,  725.4,
#          814.6,  903.8,  993. ]),
#  <a list of 10 Patch objects>)

# %%
# Determinamos que o grupo de 3 caracteres consiste na junção do ano em 2 caracteres com o número de elevadores.
# Faremos então o ano ser composto apenas dos dos primeiros caracteres, do milênio 1900 se entre 19 e 99, e do milênio 2000 se entre 00 e 18
x = ano3d.astype('str').str[:2].astype('int')
grupo1 = (x >= 19) & (x <=99)
grupo2 = ~grupo1
ano3d.loc[grupo1] = x[grupo1] + 1900
ano3d.loc[grupo2] = x[grupo2] + 2000
hist(ano3d)
# Out:
# (array([ 27.,  67.,  54.,  81.,  44.,  11.,   1.,   2.,   1.,  45.]),
#  array([ 1919. ,  1928.9,  1938.8,  1948.7,  1958.6,  1968.5,  1978.4,
#          1988.3,  1998.2,  2008.1,  2018. ]),
#  <a list of 10 Patch objects>)

# %%
# Verificar como está o grupo com 4 dígitos.
hist(ano4d)
# Out:
# (array([  5.00000000e+00,   9.24400000e+03,   1.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           0.00000000e+00,   1.00000000e+00,   0.00000000e+00,
#           1.00000000e+00]),
#  array([ 1013. ,  1895.8,  2778.6,  3661.4,  4544.2,  5427. ,  6309.8,
#          7192.6,  8075.4,  8958.2,  9841. ]),
#  <a list of 10 Patch objects>)

# %%
# Tratar anos inferiores a 1920 e  superiores a 2017 como None.
ano4d.loc[ano4d > 2017] = None
ano4d.loc[ano4d < 1920] = None

# %%
hist(ano4d[~ano4d.isnull()])
# Out:
# (array([   21.,    72.,   248.,   866.,   942.,  1166.,  1338.,   673.,
#           999.,  2912.]),
#  array([ 1920. ,  1929.7,  1939.4,  1949.1,  1958.8,  1968.5,  1978.2,
#          1987.9,  1997.6,  2007.3,  2017. ]),
#  <a list of 10 Patch objects>)

# %%
# Comprovar que os grupos são disjuntos.
(ano3d & ano4d).sum()
# Out:
# 0

# %%
# Reatribui variável ao DataFrame.
ano.loc[ano3d.index] = ano3d
ano.loc[ano4d.index] = ano4d
dfc['ano'] = ano[~ano.isnull()].astype('int')

# Remover variáveis auxiliares.
del ano, ano3d, ano4d, grupo1, grupo2


# Verifica como ficou.
hist(dfc.ano[~dfc.ano.isnull()])
# Out:
# (array([   46.,   134.,   274.,   982.,   986.,  1177.,  1394.,   685.,
#          1106.,  2786.]),
#  array([ 1919. ,  1928.9,  1938.8,  1948.7,  1958.6,  1968.5,  1978.4,
#          1988.3,  1998.2,  2008.1,  2018. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Tratar variável 'elevadores'

# %%
hist(dfc.elevadores[~dfc.elevadores.isnull()])
# Out:
# (array([ 13739.,    594.,    656.,    806.,    980.,    620.,    403.,
#            326.,    401.,    459.]),
#  array([  1. ,  10.8,  20.6,  30.4,  40.2,  50. ,  59.8,  69.6,  79.4,
#          89.2,  99. ]),
#  <a list of 10 Patch objects>)

# %%
# Determinamos arbitrariamente que não podem existir mais de 10 elevadores em um prédio. 
# Iremos reatribuir a variável 'elevadores' com o último digito.
elev = dfc.elevadores[~dfc.elevadores.isnull()]
elev = elev.astype('int').astype('str').str[-1:].astype('int')
hist(elev)
# Out:
# (array([  6.00000000e+00,   2.97200000e+03,   1.21160000e+04,
#           1.81500000e+03,   1.62200000e+03,   1.26000000e+02,
#           2.73000000e+02,   1.50000000e+01,   3.00000000e+01,
#           9.00000000e+00]),
#  array([ 0. ,  0.9,  1.8,  2.7,  3.6,  4.5,  5.4,  6.3,  7.2,  8.1,  9. ]),
#  <a list of 10 Patch objects>)

# %%
# Reatribuir a variável 'elevadores' ao DataFrame.
dfc.loc[elev.index]['elevadores'] = elev.astype('int')

# Remover variávies auxiliáres.
del elev

# %% [markdown]
# ### Tratar variável 'andares'.

# %%
# Verifica como está a variável.
andares = dfc.andar
hist(andares[~andares.isnull()])
# Out:
# (array([  2.73100000e+04,   2.85370000e+04,   5.44300000e+03,
#           6.02000000e+02,   1.10000000e+01,   5.00000000e+00,
#           3.00000000e+00,   1.00000000e+00,   2.00000000e+00,
#           1.00000000e+00]),
#  array([  0.,   8.,  16.,  24.,  32.,  40.,  48.,  56.,  64.,  72.,  80.]),
#  <a list of 10 Patch objects>)

# %%
d = z.pd.DataFrame(index=dfc.index)

d['ano'] = df.carac.apply(obtem_ano)
d['andar'] = dfc.andar
d = d[~d.ano.isnull() & ~d.andar.isnull()]
d.describe()
# Out:
#                ano        andar
# count  8948.000000  8948.000000
# mean   1931.331024     8.994300
# std     318.222728     4.969255
# min     101.000000     2.000000
# 25%    1967.000000     5.000000
# 50%    1985.000000     8.000000
# 75%    2010.000000    12.000000
# max    9841.000000    35.000000

# %%
# Verificar se o últimos 2 caracteres de ano são iguais ao númeo de andares.
ano = d.ano[~d.ano.isnull()].astype('int').astype('str')
andar = d.andar[~d.andar.isnull()].astype('int').astype('str')
x = ano.str[-2:]
y = andar.str[:2]
(x == y).sum()
# Out:
# 143

# %%
# Verificamos manualmente com alguns exemplos abaixo que é coincidência.
d[x == y]
# Out:
#           ano  andar
# id
# 5538862  2010     10
# 5829133  2014     14
# 5612293  2013     13
# 4927657  2010     10
# 6193876  2014     14
# 5941909  2012     12
# 6231669  2013     13
# 5024322  2010     10
# 6231175  2012     12
# 6016404  2012     12
# 5687508  2010     10
# 5957341  2012     12
# 5189064  2012     12
# 5310984  2010     10
# 6406372  2012     12
# 5726727  2012     12
# 6169560  2012     12
# 5770761  2014     14
# 5915310  2014     14
# 5463319  2012     12
# 5109628  2010     10
# 5331016  2013     13
# 5597858  2013     13
# 4839150  2011     11
# 5077610  2010     10
# 6214517  2010     10
# 6162909  2010     10
# 6483430  2015     15
# 5822660  2013     13
# 5957146  2014     14
# ...       ...    ...
# 5732617  2012     12
# 4508014  2013     13
# 4584367  2014     14
# 6090890  2014     14
# 3933286  2012     12
# 5043312  2010     10
# 5465107  2013     13
# 5470660  2010     10
# 5493712  2013     13
# 5989821  2012     12
# 4934107  2013     13
# 5828788  2012     12
# 5950364  2012     12
# 5584484  2012     12
# 5604767  2010     10
# 5925395  2011     11
# 5352830  2011     11
# 5828531  2012     12
# 5327534  2013     13
# 5470632  2010     10
# 5414411  2012     12
# 5770811  2014     14
# 5604964  2010     10
# 5679256  2012     12
# 6529460  2012     12
# 5443422  2013     13
# 6204534  2013     13
# 6414195  2013     13
# 6421913  2015     15
# 6075413  2012     12
#
# [143 rows x 2 columns]

# %%
df.loc['6414195'].carac
# Out:
# 'venda [?]\r\n                                    r$ 165.000\xc2\xa0\xc2\xa0\n\n\n\n\n\n\n\nvalor do m\xc2\xb2: r$ 3.511\n\n\n\n\n\n\n2 quartos/dts.construido em 20132 elevadores\n\n\n\n47 m\xc2\xb2 area util13 andares\n\n\n\n1 vaga8 unidades por andar\n\n\nexcelente apartamento de 2 quartos proximo a vista alegre, com lazer e seguranca. a poucos metros da avenida brasil, proximo ao shopping via brasil e a rodovia presidente dutra.\n'

# %%
dfc.loc['6414195']
# Out:
# alto                         False
# andar inteiro                False
# armario                      False
# banheira                     False
# blindex                      False
# children care                False
# churrasqueira                False
# closet                       False
# cobertura                    False
# copa                         False
# dependencia                  False
# duplex                       False
# elevador privativo           False
# esquina                      False
# estacionamento visitantes    False
# frente                       False
# fundos                       False
# heliponto                    False
# hidrometro                   False
# hidromassagem                False
# jardim                       False
# lareira                      False
# linear                       False
# mezanino                     False
# piscina                      False
# playground                   False
# portaria                     False
# quadra                       False
# quarto de empregada          False
# recuado                      False
# sala de jantar               False
# salao de festas              False
# salao de jogos               False
# sauna                        False
# seguranca                     True
# sol da manha                 False
# sol da tarde                 False
# terraco                      False
# triplex                      False
# varanda                      False
# indevassavel                 False
# lateral_                     False
# unidades                         8
# andar                           13
# elevadores                      32
# ano                           2013
# Name: 6414195, dtype: object

# %%
# Reatribui variável ao DataFrame.
dfc.andar = dfc.andar[~dfc.andar.isnull()].astype('int')

# Remover vairáveis auxiliares.
del d, ano, andar, x, y

# %% [markdown]
# ## Salvar as características no banco de dados.

# %%
dfc.columns
# Out:
# Index([u'alto', u'andar inteiro', u'armario', u'banheira', u'blindex', u'children care', u'churrasqueira', u'closet', u'cobertura', u'copa', u'dependencia', u'duplex', u'elevador privativo', u'esquina', u'estacionamento visitantes', u'frente', u'fundos', u'heliponto', u'hidrometro', u'hidromassagem', u'jardim', u'lareira', u'linear', u'mezanino', u'piscina', u'playground', u'portaria', u'quadra', u'quarto de empregada', u'recuado', u'sala de jantar', u'salao de festas', u'salao de jogos', u'sauna', u'seguranca', u'sol da manha', u'sol da tarde', u'terraco', u'triplex', u'varanda', u'indevassavel', u'lateral_', u'unidades', u'andar', u'elevadores', u'ano'], dtype='object')

# %%
dfc.dtypes
# Out:
# alto                            bool
# andar inteiro                   bool
# armario                         bool
# banheira                        bool
# blindex                         bool
# children care                   bool
# churrasqueira                   bool
# closet                          bool
# cobertura                       bool
# copa                            bool
# dependencia                     bool
# duplex                          bool
# elevador privativo              bool
# esquina                         bool
# estacionamento visitantes       bool
# frente                          bool
# fundos                          bool
# heliponto                       bool
# hidrometro                      bool
# hidromassagem                   bool
# jardim                          bool
# lareira                         bool
# linear                          bool
# mezanino                        bool
# piscina                         bool
# playground                      bool
# portaria                        bool
# quadra                          bool
# quarto de empregada             bool
# recuado                         bool
# sala de jantar                  bool
# salao de festas                 bool
# salao de jogos                  bool
# sauna                           bool
# seguranca                       bool
# sol da manha                    bool
# sol da tarde                    bool
# terraco                         bool
# triplex                         bool
# varanda                         bool
# indevassavel                    bool
# lateral_                        bool
# unidades                     float64
# andar                        float64
# elevadores                   float64
# ano                          float64
# dtype: object

# %%
# Converter todas variávies para inteiro.
for col in dfc.columns:
    dfc[col] = dfc[~dfc[col].isnull()][col].astype('int')

# %%
dfc.dtypes
# Out:
# alto                           int32
# andar inteiro                  int32
# armario                        int32
# banheira                       int32
# blindex                        int32
# children care                  int32
# churrasqueira                  int32
# closet                         int32
# cobertura                      int32
# copa                           int32
# dependencia                    int32
# duplex                         int32
# elevador privativo             int32
# esquina                        int32
# estacionamento visitantes      int32
# frente                         int32
# fundos                         int32
# heliponto                      int32
# hidrometro                     int32
# hidromassagem                  int32
# jardim                         int32
# lareira                        int32
# linear                         int32
# mezanino                       int32
# piscina                        int32
# playground                     int32
# portaria                       int32
# quadra                         int32
# quarto de empregada            int32
# recuado                        int32
# sala de jantar                 int32
# salao de festas                int32
# salao de jogos                 int32
# sauna                          int32
# seguranca                      int32
# sol da manha                   int32
# sol da tarde                   int32
# terraco                        int32
# triplex                        int32
# varanda                        int32
# indevassavel                   int32
# lateral_                       int32
# unidades                     float64
# andar                        float64
# elevadores                   float64
# ano                          float64
# dtype: object

# %%
from sqlalchemy import create_engine, MetaData
import sqlalchemy

engine = create_engine(r'postgresql://postgres:1234@localhost/zap')
meta = sqlalchemy.MetaData(engine, schema='public')
meta.reflect(engine, schema='public')
pdsql = z.pd.io.sql.SQLDatabase(engine, meta=meta)

pdsql.to_sql(dfc, '_carac_explo',if_exists='replace',index=True)
z.d.__executar('ALTER TABLE public._carac_explo' + 
  ' ADD CONSTRAINT pk_carac_explo PRIMARY KEY(id);' )

# %%
# Testar a recuperação das características do banco de dados.
dft = z.get('select * from _carac_explo')
dft.describe()
# Out:
#                alto  andar inteiro       armario      banheira       blindex  \
# count  91090.000000   91090.000000  91090.000000  91090.000000  91090.000000
# mean       0.045987       0.015336      0.376375      0.004534      0.088155
# std        0.209459       0.122888      0.484479      0.067182      0.283521
# min        0.000000       0.000000      0.000000      0.000000      0.000000
# 25%        0.000000       0.000000      0.000000      0.000000      0.000000
# 50%        0.000000       0.000000      0.000000      0.000000      0.000000
# 75%        0.000000       0.000000      1.000000      0.000000      0.000000
# max        1.000000       1.000000      1.000000      1.000000      1.000000
#
#        children care  churrasqueira        closet     cobertura          copa  \
# count   91090.000000   91090.000000  91090.000000  91090.000000  91090.000000
# mean        0.041014       0.247085      0.082600      0.050236      0.182358
# std         0.198325       0.431319      0.275278      0.218433      0.386142
# min         0.000000       0.000000      0.000000      0.000000      0.000000
# 25%         0.000000       0.000000      0.000000      0.000000      0.000000
# 50%         0.000000       0.000000      0.000000      0.000000      0.000000
# 75%         0.000000       0.000000      0.000000      0.000000      0.000000
# max         1.000000       1.000000      1.000000      1.000000      1.000000
#
#           ...       sol da tarde       terraco       triplex       varanda  \
# count     ...       91090.000000  91090.000000  91090.000000  91090.000000
# mean      ...           0.001735      0.042387      0.002064      0.386925
# std       ...           0.041612      0.201471      0.045383      0.487049
# min       ...           0.000000      0.000000      0.000000      0.000000
# 25%       ...           0.000000      0.000000      0.000000      0.000000
# 50%       ...           0.000000      0.000000      0.000000      0.000000
# 75%       ...           0.000000      0.000000      0.000000      1.000000
# max       ...           1.000000      1.000000      1.000000      1.000000
#
#        indevassavel      lateral_      unidades         andar    elevadores  \
# count  91090.000000  91090.000000  21505.000000  61915.000000  18984.000000
# mean       0.046405      0.013898     43.301883      8.845352     14.523862
# std        0.210361      0.117070    269.257513      5.092037     23.768129
# min        0.000000      0.000000      1.000000      0.000000      1.000000
# 25%        0.000000      0.000000      4.000000      5.000000      2.000000
# 50%        0.000000      0.000000      4.000000      8.000000      2.000000
# 75%        0.000000      0.000000      8.000000     12.000000     14.000000
# max        1.000000      1.000000   2068.000000     80.000000     99.000000
#
#                ano
# count  9570.000000
# mean   1986.071578
# std      23.265123
# min    1919.000000
# 25%    1968.000000
# 50%    1985.000000
# 75%    2010.000000
# max    2018.000000
#
# [8 rows x 46 columns]

# %%
dft.dtypes
# Out:
# alto                           int64
# andar inteiro                  int64
# armario                        int64
# banheira                       int64
# blindex                        int64
# children care                  int64
# churrasqueira                  int64
# closet                         int64
# cobertura                      int64
# copa                           int64
# dependencia                    int64
# duplex                         int64
# elevador privativo             int64
# esquina                        int64
# estacionamento visitantes      int64
# frente                         int64
# fundos                         int64
# heliponto                      int64
# hidrometro                     int64
# hidromassagem                  int64
# jardim                         int64
# lareira                        int64
# linear                         int64
# mezanino                       int64
# piscina                        int64
# playground                     int64
# portaria                       int64
# quadra                         int64
# quarto de empregada            int64
# recuado                        int64
# sala de jantar                 int64
# salao de festas                int64
# salao de jogos                 int64
# sauna                          int64
# seguranca                      int64
# sol da manha                   int64
# sol da tarde                   int64
# terraco                        int64
# triplex                        int64
# varanda                        int64
# indevassavel                   int64
# lateral_                       int64
# unidades                     float64
# andar                        float64
# elevadores                   float64
# ano                          float64
# dtype: object

# %% [markdown]
# ## Construção da característica Bairro.

# %%
# Criar coluna de nomes de bairros sem acentos e espaços.
b = z.get('select gid,nome from bairro',id_='gid')
b['nome_s'] = b.nome.apply(z.remove_acento)

# Salva como tabela.
z.d.salva_dataframe(b, '_bairro_nome_sem_acento')
z.d.__executar('ALTER TABLE public._bairro_nome_sem_acento' + 
  ' ADD CONSTRAINT pk__bairro_nome_sem_acento PRIMARY KEY(gid);' )

# %%
# Recuperar bairros de todos os imóveis na cidade do Rio.
d = z.get('select id, b2.nome_s  from vw_imovel_rio v ' +  
    ' inner join bairro b1 on v.bairro_g = b1.nome ' + 
    ' inner join _bairro_nome_sem_acento b2 on b1.gid = b2.gid')

# Converter para uma matriz de dados dummies.
dum = z.pd.get_dummies(d.nome_s)

# Garantir que para cada registro somente 1 ocorrência tenha valor. 
# Valor esperado é 0, ZERO.
(dum.sum(axis=1) == False).sum()
# Out:
# 0

# %%
dum.head()
# Out:
#          Abolicao  Acari  Agua Santa  Alto da Boa Vista  Anchieta  Andarai  \
# id
# 5793028         0      0           0                  0         0        0
# 5558200         0      0           0                  0         0        1
# 6152163         0      0           0                  0         0        0
# 5383330         0      0           0                  0         0        0
# 5005854         0      0           0                  0         0        0
#
#          Anil  Bancarios  Bangu  Barra da Tijuca  ...    Vicente de Carvalho  \
# id                                                ...
# 5793028     0          0      0                1  ...                      0
# 5558200     0          0      0                0  ...                      0
# 6152163     0          0      0                0  ...                      0
# 5383330     0          0      0                0  ...                      0
# 5005854     0          0      0                1  ...                      0
#
#          Vidigal  Vigario Geral  Vila Isabel  Vila Kosmos  Vila Militar  \
# id
# 5793028        0              0            0            0             0
# 5558200        0              0            0            0             0
# 6152163        0              0            0            0             0
# 5383330        0              0            0            0             0
# 5005854        0              0            0            0             0
#
#          Vila Valqueire  Vila da Penha  Vista Alegre  Zumbi
# id
# 5793028               0              0             0      0
# 5558200               0              0             0      0
# 6152163               0              0             0      0
# 5383330               0              0             0      0
# 5005854               0              0             0      0
#
# [5 rows x 155 columns]

# %%
# Salvar no banco de dados.
z.d.salva_dataframe(dum,'_carac_bairro')
z.d.__executar('ALTER TABLE public._carac_bairro' + 
  ' ADD CONSTRAINT pk_carac_bairro PRIMARY KEY(id);' )
