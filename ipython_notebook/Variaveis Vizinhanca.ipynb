# %%
import zap_util as z
from xlrd import open_workbook

# %% [markdown]
# # Variável 'Média de Anos de Estudo por Bairro'

# %%
b = z.get('select gid,nome from bairro', id_=None)
b['nome'] = b.nome.apply(z.remove_acento)
wb = open_workbook('./../armazen_dados_rj/488.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
anos = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_anos_estudo'] = anos

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 158 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Freguesia _Ilha_',
#  'Freguesia _Jacarepagua_',
#  'Gericino',
#  'Lapa',
#  'Osvaldo Cruz',
#  'Vasco da Gama'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Freguesia (Ilha)', 'Freguesia (Jacarepagua)', 'Oswaldo Cruz'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Freguesia (Ilha)', 'nome'] = 'Freguesia _Ilha_'
df.loc[df.nome == 'Freguesia (Jacarepagua)','nome'] = 'Freguesia _Jacarepagua_'
df.loc[df.nome == 'Oswaldo Cruz','nome'] = 'Osvaldo Cruz'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Gericino', 'Lapa', 'Vasco da Gama'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %%
wb.release_resources()

# %% [markdown]
# # Variável 'Percentual Alfabetização'

# %%
wb = open_workbook('./../armazen_dados_rj/3132.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
perc_alf = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_perc_alf'] = perc_alf

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 160 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa', 'Vila Kosmos'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Vila Cosmos'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Vila Cosmos', 'nome'] = 'Vila Kosmos'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %% [markdown]
# # Variável 'Rendimento Nominal Médio'

# %%
wb = open_workbook('./../armazen_dados_rj/3151.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
rend = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_renda'] = rend

print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 160 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa', 'Sao Cristovao'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# {'Imperial de Sao Cristovao'}

# %%
# Ajustar nomes do arquivo para serem igual ao do banco de dados.
df.loc[df.nome == 'Imperial de Sao Cristovao', 'nome'] = 'Sao Cristovao'

# %%
# Verificar novamente bairros no banco de dados mas não  no arquivo.
# Esses bairros realmente não estão no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Lapa'}

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %% [markdown]
# # Variável 'Saneamento'.

# %%
wb = open_workbook('./../armazen_dados_rj/3169.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
sanea = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_sanea'] = sanea


print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 161 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# set()

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
# Arquivo não tem dados válidos para Lapa.
df.loc[df.nome == 'Lapa','viz_sanea'] = None
df['viz_sanea'] = df['viz_sanea'].astype(float)

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %% [markdown]
# # Variável IDH

# %%
wb = open_workbook('./../armazen_dados_rj/1172.xls')
ws = wb.sheet_by_index(0)
nomes = ws.col_values(0,1)
idh = ws.col_values(1,1)
df = z.pd.DataFrame()
df['nome'] = [str.strip(z.remove_acento(n)) for n in nomes]
df['viz_idh'] = idh


print 'Tabela bairro tem {} itens e arquivo tem {} itens.'.format(len(b), len(df))
# Out:
# Tabela bairro tem 161 itens e arquivo tem 159 itens.

# %%
# Bairros no banco de dados mas não  no arquivo.
set(b.nome.tolist()) - set(df.nome.tolist())
# Out:
# {'Gericino', 'Lapa'}

# %%
# Bairros no arquivo mas não no banco de dados.
set(df.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
b = z.pd.merge(b,df,on=['nome'], how='left')

# %% [markdown]
# # Índices de Criminalidade
#
# Os índices de criminalidade foram obtidos do Institudo de Segurança Pública do RJ pelo notebook [Capturar Info Bairros](Capturar Info Bairros.ipynb).

# %%
# AISPs da cidade do Rio de Janeiro.
aisp_idx = [2,3,4,5,6,9,14,16,17,18,19,22,23,27,31,40,41]

from xlrd import open_workbook, cellname

# Repositório dos arquivos baixados.
DIR = './../instituto_seguranca_publica/xls/'

# Construir nomes dos aqruivos.
arqs = ['2013{:0>2}'.format(i) for i in range(10,13)]+['2014{:0>2}'.format(i) for i in range(1,11)]

# Helper para indexar coluna no Excel por sua letra.
def colindex(colname):
    cols_ = 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'
    return cols_.index(colname)


# Índices de criminalidade por AISP.
indices = {}

# Carregar os índices a partir dos arquivos.
for arq in arqs[:]:
    
    wb = open_workbook(DIR+arq+'.xls')
    
    for i in aisp_idx[:]:
        crimes = indices.setdefault(i, {})
        try:
            ws = wb.sheet_by_name(u'Aisp {}'.format(i))
        except:
            ws = wb.sheet_by_name(u'Aisp{}'.format(i))
        col = colindex('S')
        crimes['viz_crm_violento'] = crimes.setdefault('viz_crm_violento',0) + \
            sum(ws.col_values(col,6, 11))
        crimes['viz_crm_roubo'] = crimes.setdefault('viz_crm_roubo',0) + \
            sum(ws.col_values(col, 22, 33))
    
        del ws
    del wb
    
df_aisp = z.pd.DataFrame(indices).T    
df_aisp['aisp'] = df_aisp.index

# %%
# De <-> para entre AISP e Bairro.
aisp_bairro = z.pd.DataFrame.from_csv('./../instituto_seguranca_publica/aisp_bairro.csv', index_col=None)

# Remover acentos.
aisp_bairro['nome'] =  aisp_bairro.nome.apply(z.remove_acento)

# %%
# Listar bairros no banco de dados mas não de<->para.
# As correções necessárias foram feitas.
set(b.nome.tolist()) - set(aisp_bairro.nome.tolist())
# Out:
# set()

# %%
# Listar bairros no banco de dados mas não de<->para.
# As correções necessárias foram feitas.
set(aisp_bairro.nome.tolist()) - set(b.nome.tolist())
# Out:
# set()

# %%
# Bairros em um único AISP.
g = aisp_bairro.groupby('nome')
s = g.size()
df_bairro = b[['gid','nome']]
nomes_unico_aisp = s[s == 1].index.tolist()
b1 = z.pd.merge(df_bairro[df_bairro.nome.isin(nomes_unico_aisp)], aisp_bairro, on=['nome'], how='left')
b1_aisp = z.pd.merge(b1, df_aisp, on=['aisp'], how='left')
del b1_aisp['aisp'],b1

# %%
# Calcular média dos indicadores para bairros em mais de um AISP.

data = []
for i in s[s>1].index.tolist():
    aispids = g.get_group(i).aisp.unique().tolist()
    data.append({'nome':i,
            'gid':b[(b.nome==i)].index.tolist()[0],
            'viz_crm_roubo':df_aisp.loc[aispids].mean().viz_crm_roubo,
            'viz_crm_violento':df_aisp.loc[aispids].mean().viz_crm_roubo
            })
    
b2_aisp = z.pd.DataFrame(data)

# %%
# Juntar tudo para salvar no banco.
df = z.pd.concat([b1_aisp, b2_aisp])
df.index = df.gid
del df['gid']
df
# Out:
#                          nome  viz_crm_roubo  viz_crm_violento
# gid
# 5                        Taua     506.370607        528.446144
# 1                     Paqueta    4871.753940       1730.203982
# 4                      Galeao     506.370607        528.446144
# 6                  Portuguesa     506.370607        528.446144
# 11             Jardim America    1247.621093        539.180020
# 7                      Monero     506.370607        528.446144
# 8                Campo Grande     548.152777        750.171811
# 34               Barros Filho    2138.462156        538.945453
# 9               Vigario Geral    1247.621093        539.180020
# 10                     Cocota     506.370607        528.446144
# 12             Jardim Carioca     506.370607        528.446144
# 16            Parada de Lucas    1247.621093        539.180020
# 13                     Pavuna    2138.462156        538.945453
# 14                   Cordovil    1247.621093        539.180020
# 15           Jardim Guanabara     506.370607        528.446144
# 17            Parque Columbia    2138.462156        538.945453
# 25               Pitangueiras     506.370607        528.446144
# 19             Penha Circular    1247.621093        539.180020
# 20                      Bangu    1422.348026        630.102144
# 56                    Turiacu    2121.794262        724.358959
# 21                     Cacuia     506.370607        528.446144
# 22                      Iraja    2138.462156        538.945453
# 31                Coelho Neto    2121.794262        724.358959
# 23                   Anchieta    2138.462156        538.945453
# 24                      Acari    2138.462156        538.945453
# 26               Costa Barros    2138.462156        538.945453
# 32                  Guadalupe    2138.462156        538.945453
# 33            Parque Anchieta    2138.462156        538.945453
# 27               Bras de Pina    1247.621093        539.180020
# 28                      Penha    1247.621093        539.180020
# ..                        ...            ...               ...
# 136               Jacarepagua     646.448508        764.408423
# 137                   Camorim    1167.358492        644.473336
# 138                   Humaita    1180.675882        423.449787
# 141            Vargem Pequena    1167.358492        644.473336
# 142                Copacabana     809.532657        805.917270
# 144                     Lagoa     777.602554        567.540861
# 145                 Itanhanga    1167.358492        644.473336
# 146                     Gavea     777.602554        567.540861
# 151                   Rocinha     777.602554        567.540861
# 147           Barra da Tijuca    1167.358492        644.473336
# 148                    Leblon     777.602554        567.540861
# 149                   Ipanema     777.602554        567.540861
# 150               Sao Conrado     777.602554        567.540861
# 152        Pedra de Guaratiba     374.149360        724.667841
# 153  Recreio dos Bandeirantes    1167.358492        644.473336
# 154                   Vidigal     777.602554        567.540861
# 155                       Joa    1167.358492        644.473336
# 161                      Lapa    4871.753940       1730.203982
# 159                   Deodoro    1422.348026        630.102144
# 160                  Gericino    1422.348026        630.102144
# 2            Freguesia _Ilha_     506.370607        528.446144
# 18          Praia da Bandeira     506.370607        528.446144
# 3                   Bancarios     506.370607        528.446144
# 143                      Leme     809.532657        805.917270
# 156        Barra de Guaratiba    1167.358492        644.473336
# 157                   Grumari    1167.358492        644.473336
# 158                      Caju    1740.699949        715.936741
# 97                     Centro    3306.226945       3306.226945
# 34                    Colegio    2130.128209       2130.128209
# 114                    Tijuca    1432.398603       1432.398603
#
# [161 rows x 3 columns]

# %% [markdown]
# # Salvar variáveis de vizinhança no banco de dados.

# %%
# Salvar variáveis de bairros no banco de dados
b = z.pd.merge(b,df,on=['nome'], how='left')
b
# Out:
#      gid                      nome  viz_anos_estudo  viz_perc_alf  viz_renda  \
# 0      5                      Taua             7.30         95.14    1359.96
# 1      1                   Paqueta             7.59         94.98    1707.33
# 2      4                    Galeao             7.17         95.58    1369.61
# 3      6                Portuguesa             9.25         97.75    1960.31
# 4     11            Jardim America             7.45         97.96    1191.23
# 5      7                    Monero            11.08         99.48    2864.67
# 6      8              Campo Grande             7.63         97.48    1361.81
# 7     34              Barros Filho             5.62         95.97     761.97
# 8      9             Vigario Geral             6.24         96.17     898.04
# 9     10                    Cocota            10.15         98.99    2000.65
# 10    12            Jardim Carioca             7.81         97.28    1593.87
# 11    16           Parada de Lucas             5.90         95.64     880.69
# 12    13                    Pavuna             7.08         97.05    1031.11
# 13    14                  Cordovil             6.92         97.37    1019.70
# 14    15          Jardim Guanabara            11.71         99.12    3565.49
# 15    17           Parque Columbia             6.39         95.90     997.12
# 16    25              Pitangueiras             7.01         95.33    1279.72
# 17    19            Penha Circular             7.86         98.09    1395.59
# 18    20                     Bangu             6.95         97.24    1087.77
# 19    56                   Turiacu             7.61         97.40    1131.05
# 20    21                    Cacuia             7.95         97.19    1454.97
# 21    22                     Iraja             8.42         98.73    1498.47
# 22    31               Coelho Neto             7.26         97.54    1058.22
# 23    23                  Anchieta             6.86         97.40    1064.79
# 24    24                     Acari             5.02         91.98     685.63
# 25    26              Costa Barros             5.71         94.52     744.13
# 26    32                 Guadalupe             7.62         98.40    1207.27
# 27    33           Parque Anchieta             7.67         98.11    1310.80
# 28    27              Bras de Pina             7.66         97.97    1280.25
# 29    28                     Penha             7.52         97.11    1202.96
# ..   ...                       ...              ...           ...        ...
# 131  131                  Botafogo            11.77         99.15    4269.21
# 132  132                      Urca            13.45         99.20    5191.48
# 133  135                      Anil             9.81         98.43    2554.59
# 134  136               Jacarepagua             6.08         93.88    1350.59
# 135  137                   Camorim             5.66         96.86    2260.63
# 136  138                   Humaita            13.11         99.69    4856.16
# 137  141            Vargem Pequena             5.63         93.86    1273.29
# 138  142                Copacabana            11.76         99.14    4170.08
# 139  144                     Lagoa            13.89         99.64    8286.46
# 140  145                 Itanhanga             6.32         94.80    1762.91
# 141  146                     Gavea            12.61         99.01    5314.21
# 142  151                   Rocinha             4.59         93.42     747.42
# 143  147           Barra da Tijuca            13.25         99.51    6834.73
# 144  148                    Leblon            12.67         99.54    6844.63
# 145  149                   Ipanema            12.54         99.38    6533.14
# 146  150               Sao Conrado            12.39         99.26    6901.97
# 147  152        Pedra de Guaratiba             7.41         97.10    1363.78
# 148  153  Recreio dos Bandeirantes             9.85         98.16    3807.88
# 149  154                   Vidigal             5.91         94.52     995.93
# 150  155                       Joa            12.65         98.36    7890.89
# 151  161                      Lapa              NaN           NaN        NaN
# 152  159                   Deodoro             7.06         97.77    1075.66
# 153  160                  Gericino              NaN         95.14     702.44
# 154    2          Freguesia _Ilha_             8.57         97.06    1606.67
# 155   18         Praia da Bandeira            10.03         99.44    2048.78
# 156    3                 Bancarios             7.76         96.63    1397.40
# 157  143                      Leme            12.06         97.12    4388.39
# 158  156        Barra de Guaratiba             6.43         98.22    1261.21
# 159  157                   Grumari             3.88         85.33     571.01
# 160  158                      Caju             5.14         93.14     806.55
#
#      viz_sanea   viz_idh  viz_crm_roubo  viz_crm_violento
# 0     0.967983  0.817173     506.370607        528.446144
# 1     0.984702  0.822264    4871.753940       1730.203982
# 2     0.910094  0.777761     506.370607        528.446144
# 3     0.944640  0.903975     506.370607        528.446144
# 4     0.952546  0.838988    1247.621093        539.180020
# 5     0.947081  0.903975     506.370607        528.446144
# 6     0.811100  0.809680     548.152777        750.171811
# 7     0.835095  0.749528    2138.462156        538.945453
# 8     0.776496  0.763330    1247.621093        539.180020
# 9     0.997628  0.860875     506.370607        528.446144
# 10    0.990782  0.836297     506.370607        528.446144
# 11    0.985146  0.745160    1247.621093        539.180020
# 12    0.921502  0.789884    2138.462156        538.945453
# 13    0.964682  0.791120    1247.621093        539.180020
# 14    0.989630  0.963001     506.370607        528.446144
# 15    0.830701  0.719627    2138.462156        538.945453
# 16    0.995078  0.858446     506.370607        528.446144
# 17    0.992067  0.826417    1247.621093        539.180020
# 18    0.930159  0.794029    1422.348026        630.102144
# 19    0.914610  0.811853    2121.794262        724.358959
# 20    0.951320  0.859195     506.370607        528.446144
# 21    0.976399  0.798364    2138.462156        538.945453
# 22    0.950132  0.805881    2121.794262        724.358959
# 23    0.919785  0.788027    2138.462156        538.945453
# 24    0.927090  0.719627    2138.462156        538.945453
# 25    0.937522  0.713210    2138.462156        538.945453
# 26    0.965370  0.809947    2138.462156        538.945453
# 27    0.940510  0.832555    2138.462156        538.945453
# 28    0.965729  0.834562    1247.621093        539.180020
# 29    0.977766  0.804251    1247.621093        539.180020
# ..         ...       ...            ...               ...
# 131   0.995697  0.952152    1180.675882        423.449787
# 132   0.996458  0.952152    1180.675882        423.449787
# 133   0.767546  0.911022     646.448508        764.408423
# 134   0.773384  0.769455     646.448508        764.408423
# 135   0.373228  0.745803    1167.358492        644.473336
# 136   0.999139  0.959008    1180.675882        423.449787
# 137   0.691088  0.745803    1167.358492        644.473336
# 138   0.999391  0.956499     809.532657        805.917270
# 139   0.999399  0.959423     777.602554        567.540861
# 140   0.448537  0.822026    1167.358492        644.473336
# 141   0.998594  0.970435     777.602554        567.540861
# 142   0.856901  0.732113     777.602554        567.540861
# 143   0.886679  0.958861    1167.358492        644.473336
# 144   0.998769  0.967067     777.602554        567.540861
# 145   0.999401  0.962151     777.602554        567.540861
# 146   0.986230  0.873369     777.602554        567.540861
# 147   0.842857  0.743630     374.149360        724.667841
# 148   0.781119  0.894470    1167.358492        644.473336
# 149   0.978575  0.873369     777.602554        567.540861
# 150   0.502008  0.958861    1167.358492        644.473336
# 151        NaN       NaN    4871.753940       1730.203982
# 152   0.912938  0.856453    1422.348026        630.102144
# 153   0.939597       NaN    1422.348026        630.102144
# 154   0.981224  0.838543     506.370607        528.446144
# 155   0.989691  0.858446     506.370607        528.446144
# 156   0.985287  0.860875     506.370607        528.446144
# 157   0.991317  0.955413     809.532657        805.917270
# 158   0.321612  0.743630    1167.358492        644.473336
# 159   0.000000  0.894470    1167.358492        644.473336
# 160   0.998256  0.753206    1740.699949        715.936741
#
# [161 rows x 9 columns]

# %%
b.index = b.gid
del b['gid']
z.d.salva_dataframe(b, '_bairro_var_vizinhanca')
