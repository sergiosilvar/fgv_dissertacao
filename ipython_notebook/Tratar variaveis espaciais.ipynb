# %%
# %pylab inline

import zap_util as z
z.set_style()
DIR = './../texto/img/'
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['plot']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
df = z.get('select * from vw_distancia')

# %%
dfd = df[[i for i in df.columns.tolist() if i.find('id_') ]]
dfd.describe()
# Out:
#         dist_favela  dist_bombeiro   dist_centro  dist_centro_lng  \
# count  53581.000000   53581.000000  53581.000000     53581.000000
# mean       0.614571       1.654962     13.449490        11.045882
# std        0.602575       1.211603      9.442173        10.050282
# min        0.000000       0.007348      0.100943         0.000048
# 25%        0.266550       0.790498      6.313240         2.002879
# 50%        0.456292       1.260291      9.517048         7.399002
# 75%        0.726724       2.278280     19.973464        18.624556
# max        6.077876       9.115537     55.865946        55.821855
#
#        dist_centro_lat  dist_delegacia    dist_lagoa  dist_logradouro  \
# count     53581.000000    53581.000000  53581.000000     53581.000000
# mean          5.682883        3.155151      4.007125         0.291721
# std           3.852094        4.235173      3.962794         0.442050
# min           0.000438        0.003547      0.000000         0.000000
# 25%           2.173069        0.703789      0.903696         0.023365
# 50%           5.618187        1.316363      3.004720         0.155462
# 75%           8.578444        3.408146      5.493559         0.373339
# max          17.644322       17.703650     27.758219         6.536509
#
#          dist_metro    dist_praia  dist_saude_publica  dist_saude_privada  \
# count  53581.000000  53581.000000        53581.000000        53581.000000
# mean       6.858814      3.600355            1.037211            0.324475
# std        7.911428      3.445466            0.974125            0.349841
# min        0.008567      0.000000            0.000000            0.000000
# 25%        0.582056      0.693509            0.374664            0.105035
# 50%        2.450077      2.117784            0.683850            0.226777
# 75%       12.879695      6.167344            1.316366            0.435816
# max       39.019140     22.218399            5.989452            7.596612
#
#           dist_trem
# count  53581.000000
# mean       6.680159
# std        4.738935
# min        0.003328
# 25%        2.207006
# 50%        6.341003
# 75%       10.334973
# max       17.702176

# %%
def plot(column, legend):
    z.plot_boxhist(dfd[column], u'Variável '+column, 
        u'Distância {} em Km.'.format(legend)  )
    savefig(DIR+'var_'+column+'_boxhist.png')

# %%
plot('dist_favela', u'à favela')

# %%
plot('dist_bombeiro', u'à corpo de bombeiros')

# %%
plot('dist_centro', 'ao centro da cidade')

# %%
plot('dist_centro_lng', 'longitudinal ao centro da cidade')

# %%
plot('dist_centro_lat', 'latitudinal ao centro da cidade')

# %%
plot('dist_delegacia', u'à delegacia de Polícia Civil')

# %%
plot('dist_lagoa', u'às lagoas')

# %%
plot('dist_logradouro', u'aos principais logradouros')

# %%
plot('dist_metro', u'às estações de metrô')

# %%
plot('dist_praia', u'às praias')

# %%
plot('dist_saude_publica', u'às unidaes de saúde pública')

# %%
plot('dist_saude_privada', u'às unidades de saúde privada')

# %%
plot('dist_trem', u'às estações de trem')
