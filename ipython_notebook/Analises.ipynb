# %%
# %pylab inline

import zap_util as z

import geopandas as gp

rcParams['figure.figsize'] = 8,8
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = z.get('select id,area,preco,condominio,m2,garagem,quartos,suites,lat,lng from vw_imovel')
df.isnull().sum()
# Out:
# area              0
# preco             0
# condominio     7448
# m2                0
# garagem       11640
# quartos           0
# suites        22462
# lat               0
# lng               0
# dtype: int64

# %%
# Remover anúncios sem quartos.
df = df[~df.quartos.isnull()]

# Tratar NA como 0.
df.fillna(0,inplace=True)

df.describe()
# Out:
#                area         preco    condominio            m2       garagem  \
# count  58715.000000  58715.000000  58715.000000  58715.000000  58715.000000
# mean     119.831849   1272.559764      2.705318     10.147332      1.217934
# std       81.788546   1271.363151     52.483161      5.945197      0.903993
# min       15.000000     45.000000      0.000000      0.381426      0.000000
# 25%       70.000000    499.000000      0.308000      6.048387      1.000000
# 50%       92.000000    839.000000      0.580000      8.589744      1.000000
# 75%      140.000000   1550.000000      0.950000     12.432432      2.000000
# max      895.000000   9990.000000   4500.000000     72.500000      5.000000
#
#             quartos        suites           lat           lng
# count  58715.000000  58715.000000  58715.000000  58715.000000
# mean       2.605297      0.868483    -22.952331    -43.284897
# std        0.861394      0.931543      0.045428      0.098106
# min        1.000000      0.000000    -23.066667    -43.721668
# 25%        2.000000      0.000000    -22.985210    -43.357819
# 50%        3.000000      1.000000    -22.956388    -43.249481
# 75%        3.000000      1.000000    -22.922871    -43.197077
# max        5.000000      5.000000    -22.786389    -43.157761

# %%
# Plot para verificar a aglomeração dos imóveis.
g = gp.GeoDataFrame.from_postgis('select * from cidade',z.con)
g.plot(alpha=0);
scatter(df.lng,df.lat,alpha=0.1);

# %%
f,a = subplots(1,2,sharey=True)
f.set_size_inches(12,4)
a0,a1 = a
bins=100
a0.hist(df.preco,bins=bins);
a0.set_title(u'Histograma preço');
a0.set_ylabel('Quantidade')

a1.hist(df.m2,bins=bins)
a1.set_title(u'Histograma $R$/m^2$');

# %%
cov(df.preco,df.area)
# Out:
# array([[ 403814.51579027,   13890.21838092],
#        [  13890.21838092,    1191.87494787]])

# %%
cov([1,2,3,4],[-2,-4,-6,-8])
# Out:
# array([[ 1.66666667, -3.33333333],
#        [-3.33333333,  6.66666667]])

# %%
from pandas.tools.plotting import scatter_matrix

sm = scatter_matrix(df, alpha=0.2, figsize=(16, 16), diagonal='kde');

# %%
sm = scatter_matrix(df[['preco','m2','lat','lng']])

# %%
from matplotlib.colors import LogNorm
f,a = subplots(1,2,sharey=False)
f.set_size_inches(12,4)
a0,a1 = a
bins=30
alpha = 0.3
norm = LogNorm()
a0.hexbin(df.preco,df.lat, norm=norm);
a0.set_title(u'Hexbin preço');
a0.set_ylabel('Quantidade')

a1.hexbin(df.m2,df.lat, norm=norm)
a1.set_title(u'Hexbin $m^2$');

# %%
dfx = z.get('select * from vw_distancia')
df = z.pd.merge(df,dfx)

# %%
scatter(df.preco,df.dist_centro)

# %%
q2 = df[df.quartos == 2]

# %%
df.dist_centro.hist(bins=30)

# %%
q2.preco.hist(bins=100)

# %% [markdown]
# Visão geral do dataset.

# %%
df.describe()
# Out:
#                area         preco    condominio            m2       garagem  \
# count  46834.000000  46834.000000  46834.000000  46834.000000  46834.000000
# mean      89.713413    873.028328      0.553867      9.493339      0.997096
# std       34.523542    635.464016      0.406052      5.009731      0.720702
# min       16.000000     45.000000      0.000000      0.735294      0.000000
# 25%       66.000000    433.625000      0.295000      5.818182      1.000000
# 50%       82.000000    685.000000      0.500000      8.088235      1.000000
# 75%      110.000000   1150.000000      0.780000     12.000000      1.000000
# max      199.000000   5570.000000      2.990000     29.988889      4.000000
#
#             quartos        suites           lat           lng
# count  46834.000000  46834.000000  46834.000000  46834.000000
# mean       2.322565      0.635478    -22.946434    -43.283989
# std        0.648406      0.661526      0.045673      0.097443
# min        1.000000      0.000000    -23.066667    -43.721668
# 25%        2.000000      0.000000    -22.980431    -43.357047
# 50%        2.000000      1.000000    -22.942360    -43.250000
# 75%        3.000000      1.000000    -22.918671    -43.197077
# max        3.000000      3.000000    -22.786389    -43.157761

# %% [markdown]
# Visão geral da distribuição espacial do imóveis.

# %%
'''
data = random.random((25,25)) # 25x25 matrix of values
pcolor(data)
colorbar()
'''
from matplotlib.colors import LogNorm
hist2d(df.lng, df.lat,norm=LogNorm(),bins=100)
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x000000000D881688>

# %%
hexbin(df.lng,df.lat,norm=LogNorm())
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x000000000C4CD048>

# %%
# Plot quartos
qts = [df[df.quartos==i] for i in range(1,5)]


#f,a = subplots(len(qts)/2, len(qts)/2, sharey=True, sharex = True)
#f.set_size_inches(f.get_size_inches()[0]*len(qts),f.get_size_inches()[1]*len(qts))
#a = a.ravel()
#a[0].scatter(qts[0].lng, qts[0].lat, alpha=0.2 );


#for i in range(len(qts)):
#    a[i].scatter(qts[i].lng, qts[i].lat, alpha=0.2 )
#    a[i].set_title(u'Localização dos {} imóveis com {} quarto(s).'.format(len(qts[i]),i+1))
len(qts[2])
# Out:
# 19835

# %%
scatter(df.m2, df.lat, alpha=0.2)

# %%
! True
# Out:
# 'True' nÆo ‚ reconhecido como um comando interno
# ou externo, um programa oper vel ou um arquivo em lotes.

# %%
from  scipy.stats import zscore

dfz = df[numeric_columns].apply(zscore)
dfz.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-4cad5ad1f0cd> in <module>()
#       1 from  scipy.stats import zscore
#       2
# ----> 3 dfz = df[numeric_columns].apply(zscore)
#       4 dfz.describe()
#
# NameError: name 'numeric_columns' is not defined

# %%
# Plot histograma de preço e m2 e zscore.
qtd = 4
f,a = subplots(qtd/2,qtd/2)
a = a.ravel()
f.set_size_inches(f.get_size_inches()[0]*qtd,f.get_size_inches()[1]*qtd)
a[0].hist(df.preco);
a[0].set_title(u'Hist Preço');

a[1].hist(df.m2);
a[1].set_title(u'Hist $m^2$');

a[2].hist(dfz.preco);
a[2].set_title(u'Hist Zscore Preço');

a[3].hist(dfz.m2);
a[3].set_title(u'Hist Zscore $m^2$');

# %%
f, (ax1,ax2) = subplots(1,2,sharey=True)
f.set_size_inches(9,4)

ax1.hist(dfz.preco,bins=100,normed=True)
ax1.set_title(u'Distribuicao de Preço')
ax2.hist(dfz.m2,bins=100,normed=True)
ax2.set_title(u'Distribuicao de $m^2$')

show()

# %%
dfz.loc[df.bairro_g=='Leme'].preco.hist()

# %%
f, (ax1,ax2) = subplots(1,2,sharey=True)
f.set_size_inches(9,4)

ax1.hist(df.preco,bins=100,normed=True)
ax1.set_title(u'Distribuicao de Preço')
ax2.hist(df.m2,bins=100,normed=True)
ax2.set_title(u'Distribuicao de $m^2$')

show()

# %%
df.m2.describe()

# %% [markdown]
# ## Machine Learning

# %%
df.head()

# %%
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing

def linear_reg(X,y):
    '''
        Helper para usar regressao linear do sklearn.
    '''
    lr = LinearRegression(fit_intercept=True)
    lr.fit(X,y)
    p = lr.predict(X)
    rmse = sum((p-y)**2)/len(p)
    return rmse

errors = []
rmse = linear_reg(df[['lat','lng']],df.preco)
errors.append(rmse)

# %%
e = linear_reg(df[['area','quartos','suites']], df.preco)
errors.append(e)

# %%
e = linear_reg(df[['area','quartos','suites','condominio']], df.preco)
errors.append(e)

# %%
e = linear_reg(df[['area', 'quartos', 'suites', 'condominio', 'garagem' ]], df.preco)
errors.append(e)

# %%
e = linear_reg(df[['area', 'quartos', 'suites', 'condominio', 'garagem', 'lat', 'lng']], df.preco)
errors.append(e)

# %%
def autolabel(rects):
    # attach some text labels
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x()+rect.get_width()/2., 1.05*height, '%d'%int(height),
                ha='center', va='bottom')
fig,ax = subplots()        
rct = ax.bar(range(len(errors)),errors, width=0.3)
autolabel(rct)

# %%
import statsmodels.api as sm
import statsmodels.formula.api as smf

formula = 'df.preco ~ df.area + df.condominio + df.garagem + df.quartos + df.suites+ df.lat+ df.lng'
lm = sm.formula.ols(formula, df).fit()
print lm.summary()

# %%
lr1 = LinearRegression(fit_intercept=True)
X = df[['area' , 'condominio','garagem','quartos','suites']]
y = df.preco
lr1.fit(X,y)
lr1.coef_,lr1.intercept_

# %%
lr1 = LinearRegression(fit_intercept=True)
X = df[['area' , 'condominio','garagem','quartos','suites','lat','lng']]
y = df.preco
lr1.fit(X,y)
lr1.coef_,lr1.intercept_

# %%
tijuca = df[df.bairro_g == 'Tijuca']
tijuca.describe()

# %%
from  random import gauss

x = [gauss(15,2) for x in range(10)]

mu = 16.6
n = 10
std(x,ddof=1)
# Out:
# 2.9106058721467729

# %%
# Out:
# (3.0680479756815471, 3.0680479756815471)
