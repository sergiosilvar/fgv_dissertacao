# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.cluster import KMeans
import zap_util

# %%
df = zap_util.df
X = df[['lng','lat']].as_matrix()

# %%
rcParams['figure.figsize'] = (12,8)

# %%
cmap = cm.get_cmap('jet')
kmeans = KMeans(8)
y = kmeans.fit(X)
scatter(X[:,0],X[:,1],marker='.',c=y.labels_,cmap=cmap)
mu = kmeans.cluster_centers_
scatter(mu[:,0],mu[:,1],c=unique(y.labels_),cmap=cmap,marker='*',s=400)
